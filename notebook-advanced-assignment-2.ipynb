# %% [markdown]
# # IT3212

# %% [markdown]
# ## Config

# %%
lemmatize = False

# %% [markdown]
# ## Importing libraries

# %%
# Standard libraries
import numpy as np
import pandas as pd
import re
import string

# NLTK tools and datasets
import nltk
from nltk.tokenize import word_tokenize, TweetTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.util import ngrams
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Uncomment if you need to download NLTK data packages
# nltk.download('stopwords')
# nltk.download('wordnet')
# nltk.download('vader_lexicon')

# Text processing
from textblob import TextBlob
import contractions

# Visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (accuracy_score, classification_report, 
                             confusion_matrix, roc_curve, auc)
from sklearn.model_selection import cross_val_predict

# Miscellaneous
from collections import Counter
from urllib.parse import unquote
from scipy import stats
import chardet
import pprint

# %%
def split_train_test(filepath):
    df = pd.read_csv(filepath, encoding='utf-8')
    train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)
    train_data = train_data.reset_index(drop=True)
    test_data = test_data.reset_index(drop=True)
    return train_data, test_data

filepath = 'data/disaster-tweets-utf8.csv'
df_train, df_test = split_train_test(filepath)
df_train.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  778253309    False   finalized                   5     8/27/15 16:07
# 1  778251995    False   finalized                   5     8/27/15 20:16
# 2  778247239    False   finalized                   5      8/30/15 0:15
# 3  778255430    False   finalized                   5     8/27/15 17:03
# 4  778255609    False   finalized                   5     8/27/15 22:11
#
#      choose_one  choose_one:confidence choose_one_gold   keyword  \
# 0  Not Relevant                 1.0000             NaN  screamed
# 1  Not Relevant                 1.0000             NaN  mudslide
# 2  Not Relevant                 1.0000             NaN   collide
# 3      Relevant                 0.7978             NaN   wounded
# 4  Not Relevant                 1.0000             NaN   wrecked
#
#                     location  \
# 0                        NaN
# 1                  Edinburgh
# 2                planeta H2o
# 3                        NaN
# 4  Sunny Southern California
#
#                                                 text       tweetid  \
# 0  i dont even remember slsp happening i just rem...  6.291070e+17
# 1  @hazelannmac ooh now I feel guilty about wishi...  6.290180e+17
# 2  Soultech - Collide (Club Mix) http://t.co/8xIx...  6.290920e+17
# 3  Police Officer Wounded Suspect Dead After Exch...  6.291190e+17
# 4  Cramer: Iger's 3 words that wrecked Disney's s...  6.290800e+17
#
#          userid
# 0  2.327739e+08
# 1  2.750220e+07
# 2  6.052387e+08
# 3  2.305930e+09
# 4  2.464266e+07

# %% [markdown]
# ## 1. Preprocessing

# %%
lemmatizer = WordNetLemmatizer()
tokenizer = TweetTokenizer()

def filter_rows_by_confidence_and_decision(df, confidence_threshold):
    df = df[df['choose_one:confidence'] >= confidence_threshold]
    df = df[df['choose_one'] != "Can't Decide"]
    return df

def map_choose_one_to_y(df):
    df['target'] = df['choose_one'].apply(lambda choice: 1 if choice == 'Relevant' else 0)
    return df

def clean_text(text):
    text = re.sub(r'https?://\S+', '', text)
    text = re.sub(r'\n', ' ', text)
    text = re.sub('\s+', ' ', text).strip()
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = text.lower()
    text = ' '.join([word for word in text.split() if word not in stopwords.words("english")])
    if lemmatize:
        text = ' '.join([lemmatizer.lemmatize(word) for word in text.split()])
    text = contractions.fix(text)
    text = ' '.join(tokenizer.tokenize(text))
    return text

def clean_keyword(keyword):
    return unquote(keyword) if pd.notnull(keyword) else ''

def clean_data(df):
    df['keyword'] = df['keyword'].apply(clean_keyword).apply(str.lower)
    df['text_raw'] = df['text']
    df['text'] = df['text'].apply(clean_text)
    return df

initial_count = df_train.shape[0]
confidence_threshold = 0.7

df_train = filter_rows_by_confidence_and_decision(df_train, confidence_threshold)
print("Removed {} of total: {} rows. Remaining rows: {}".format(initial_count - df_train.shape[0], initial_count, df_train.shape[0]))

features_to_keep = ['target', 'text', 'keyword']

df_train = map_choose_one_to_y(df_train)
df_train = df_train[features_to_keep]
df_train = clean_data(df_train)

count_initial = df_train.shape[0]
df_train = df_train.drop_duplicates(subset=['text'])
print("Removed {} duplicated rows.".format(count_initial - df_train.shape[0]))


# Preprocess the test data as well
df_test = map_choose_one_to_y(df_test)
df_test = df_test[features_to_keep]
df_test = clean_data(df_test)

df_test.head()
# Out:
# Removed 2167 of total: 8700 rows. Remaining rows: 6533
# Removed 635 duplicated rows.
#    target                                               text    keyword  \
# 0       1  sunset looked like erupting volcano initial th...    volcano
# 1       1  7294 nikon d50 61 mp digital slr camera body 2...   body bag
# 2       0  mentaltwitter note make sure smoke alarm batte...      smoke
# 3       0  emergency need part 2 3 nashnewvideo nashgrier...  emergency
# 4       0  whelen model 295ss100 siren amplifier police e...      siren
#
#                                             text_raw
# 0  The sunset looked like an erupting volcano ......
# 1  #7294 Nikon D50 6.1 MP Digital SLR Camera Body...
# 2  Mental/Twitter Note: Make sure my smoke alarm ...
# 3  ?????? EMERGENCY ?????? NEED PART 2 and 3!!! #...
# 4  WHELEN MODEL 295SS-100 SIREN AMPLIFIER POLICE ...

# %% [markdown]
# ## 2. Extracting features

# %%
def extract_features(df): 
    # Create new column for text length
    df['text_length'] = df['text_raw'].apply(len)
    # Extract the number of hashtags
    df["hashtag_count"] = df["text_raw"].apply(lambda x: len([c for c in str(x) if c == "#"]))

    # Extract the number of mentions
    df["mention_count"] = df["text_raw"].apply(lambda x: len([c for c in str(x) if c == "@"]))

    # Extract the `has_url` feature
    df["has_url"] = df["text_raw"].apply(lambda x: 1 if "http" in str(x) else 0)
    return df

# Write the updated dataframe to a CSV file
df_train = extract_features(df_train)
df_test = extract_features(df_test)

# %% [markdown]
# ### Embedding `text` column using `Word2Vec`

# %%
VECTOR_SIZE = 25

tokenized_text = df_train['text'].apply(lambda x: x.split())

import gensim.downloader as api
model_w2v = api.load("glove-twitter-25")

# %%
VECTOR_SIZE = 25
VECTOR_SIZE
# Out:
# 25

# %%
oow_tokens = []

def embed_text_feature(df, col, model, vector_size):
    def tokens_to_vectors(text_tokens) -> np.ndarray:
        oow = []
        vectors = np.zeros((len(text_tokens), vector_size))

        # embed each token (word-ish) in the text. If the token is not in the model's vocabulary, embed it as a zero vector.
        for i, token in enumerate(text_tokens):
            try:
                vectors[i] = model[token]
            except KeyError:  # Token not in the model's vocabulary
                oow.append(token)
                vectors[i] = np.zeros(vector_size)

        # if all tokens were zero vectors, i.e. all words not in the model's vocabulary, return a zero vector
        if np.all(vectors == 0):
            return np.zeros(vector_size)
        
        oow_tokens.append(oow)
        return vectors.mean(axis=0)

    embeddings = []
    for tokens in df[col].apply(lambda x: x.split()):
        embeddings.append(tokens_to_vectors(tokens))

    return pd.DataFrame(np.vstack(embeddings), columns=[f'{col}_w2v_{i}' for i in range(vector_size)])

df_train_text_embedded_w2v = embed_text_feature(df_train, 'text', model_w2v, VECTOR_SIZE)
df_test_text_embedded_w2v = embed_text_feature(df_test, 'text', model_w2v, VECTOR_SIZE)

print(f"Out of vocabulary tokens")
# filter out empty lists
pprint.pprint([tokens for tokens in oow_tokens if tokens])

df_train_text_embedded_w2v.shape
# Out:
# Out of vocabulary tokens
# [['hazelannmac', 'hatman'],
#  ['soultech'],
#  ['3'],
#  ['safyuan'],
#  ['thesmallclark'],
#  ['ashniggas'],
#  ['wbre', 'wyou'],
#  ['clockworkheart'],
#  ['6', '2015', '2082676773', 'idfire'],
#  ['11yearold', '11yearold'],
#  ['ppact', 'hillaryclinton', 'destructiondefundpp'],
#  ['scalpium'],
#  ['janenelson', '097', 'stephenscifi'],
#  ['rosenthalauthor'],
#  ['artectura', '2015', 'n36'],
#  ['ravioliwith'],
#  ['imsushickoflove', 'alekalicante'],
#  ['6'],
#  ['errrr', 'notgoingoutinthat', 'hellonwheelsamc', 'howfans', 'talkinghell'],
#  ['crossborder', 'timesofindia'],
#  ['1980', 'rorington', '95'],
#  ['sensorsenso', 'beckarnley', '9395', '90', '28lv6'],
#  ['360wisenews'],
#  ['du19'],
#  ['70', '69', '1945', '200000'],
#  ['2in1', '20'],
#  ['mh370', 'r̩union'],
#  ['33', 'craykain'],
#  ['bosvsnyy'],
#  ['stefsy', '14'],
#  ['bytorrecilla', '600000'],
#  ['501', 'maddddd'],
#  ['alllivesmatter'],
#  ['5'],
#  ['kinggerudo', 'moblins'],
#  ['itblank', 'expressioncheeks', 'facemarvins'],
#  ['flavafraz', '21', 'whatcanthedo'],
#  ['carfest'],
#  ['16yr'],
#  ['kayhow', '21', 'coinflip'],
#  ['thirtyfive'],
#  ['sidjsjdjekdjskdjd'],
#  ['666', '3'],
#  ['facilitydude', 'facilitiesmanagement'],
#  ['weallheartonedirection', 'wouldn۪t', 'i۪m'],
#  ['don۪t'],
#  ['natethewolf', '14'],
#  ['thoutaylorbrown'],
#  ['asukager'],
#  ['rantipozi', 'cucks'],
#  ['menahem', '22', 'moshav', 'safsufa', '361'],
#  ['2', 'butgod'],
#  ['localeventcountdown', '8', 'rstoday'],
#  ['upwindstorm'],
#  ['mrsbinker', 'emiliorivera', '48', 'davidlabrava'],
#  ['cityofmemphis'],
#  ['16yr'],
#  ['15'],
#  ['suicidebycop'],
#  ['battlehork'],
#  ['injuryi', '495', '31', '97georgia'],
#  ['lightningwolf'],
#  ['70', 'wroug'],
#  ['creelyou', 'dobut'],
#  ['szmnextdoor'],
#  ['explosionproof', 'z10'],
#  ['mh370'],
#  ['cityofcalgary', 'yycstorm'],
#  ['29'],
#  ['300000', '1200000', '11000000', '2015'],
#  ['klinenberg'],
#  ['16yr'],
#  ['24'],
#  ['linkury'],
#  ['thesewphist', 'fuckfacewineisdumbcom'],
#  ['70year'],
#  ['712c'],
#  ['plantcovered'],
#  ['edwing'],
#  ['salvadors', '4', '8'],
#  ['2', 'mumbaitimes'],
#  ['epicinsanity', 'grimrail'],
#  ['spencerellmore', 'centretransfer'],
#  ['prophetmuhammad'],
#  ['mygc'],
#  ['300'],
#  ['wedaug', '5th'],
#  ['beinart'],
#  ['i95', '548', '3', 'i95', '548', '3'],
#  ['donbas'],
#  ['stury'],
#  ['2016'],
#  ['23800'],
#  ['molecularly'],
#  ['mh370'],
#  ['bickleton', '25', '2'],
#  ['4', 'japton', '25', '50'],
#  ['70th'],
#  ['votejkt', '48id', 'mbataweel'],
#  ['appropriates'],
#  ['05', '931pm', '05', '1015pm'],
#  ['you۪re'],
#  ['tomcatarts'],
#  ['coolweird'],
#  ['rlauren', '83199', 'xojademarie', '124'],
#  ['animallogic', 'lotg'],
#  ['36'],
#  ['3nach9', 'hbwahl', 'weserkurier', 'hbbuergerschaft', 'jerusalempost'],
#  ['clnv'],
#  ['israelnews'],
#  ['2'],
#  ['6th', '70th', 'abomb', '70000'],
#  ['sbee'],
#  ['fieldworksmells'],
#  ['16'],
#  ['oliviaapalmerr'],
#  ['12', '72w', '4wd'],
#  ['valleywx'],
#  ['denisleary', 'trueheroes'],
#  ['avigdorliberman', 'susiya'],
#  ['morels', 'farmr', 'martsunmushroom', 'foragesecret'],
#  ['lavamobiles', '3g', '402'],
#  ['appleofficlal', '12', 'hrsto', '8'],
#  ['huebels'],
#  ['21st'],
#  ['suruc', '22'],
#  ['smhrn', 'mhtw', '4fnet'],
#  ['58hif'],
#  ['thrarchives', '1928'],
#  ['cityofcalgary'],
#  ['gmmbc'],
#  ['2013', '710'],
#  ['lt3'],
#  ['05th', '2029'],
#  ['sassynreal'],
#  ['toread'],
#  ['wweapons'],
#  ['12', '23km', '2015080', '5', '235409', '2015080', '5', '16'],
#  ['bitterroot'],
#  ['shtballplayrsdo'],
#  ['minhazmerchant'],
#  ['twia'],
#  ['jusstdoitgirl'],
#  ['clearedincident', 'injuryi', '495', '31', '97georgia'],
#  ['hellotybeeren'],
#  ['500'],
#  ['ti5'],
#  ['56'],
#  ['spencervh'],
#  ['05082015'],
#  ['melindahaunton'],
#  ['12'],
#  ['harveymaine', 'roomr'],
#  ['misfortunebut'],
#  ['67'],
#  ['ltpgtan'],
#  ['mh370', 'yahoonewsdigest'],
#  ['hempoil', 'marijuananews'],
#  ['1130bst', 'a10gtparis', 'a40', 'a7', 'a1', 'a2gthanover', 'a5'],
#  ['linkury'],
#  ['justinling'],
#  ['mh370'],
#  ['7a730p'],
#  ['80'],
#  ['america۪s'],
#  ['portmoody', 'kemsley', 'gatensbury'],
#  ['atchisonsean'],
#  ['revolutionblight', 'acebabes', 'healthweekly', '1', 'amateurnester'],
#  ['alloutash', '23sn', 'brotherboyfriend', 'mdva'],
#  ['bioterror', 'rickperry', 'gopdebate'],
#  ['brothernlaw', 'riooooos'],
#  ['johnnieguilbert'],
#  ['2013', 'saddlebrooke'],
#  ['chronicillness', 'gtgtgt'],
#  ['bigamist', '8'],
#  ['pandaw'],
#  ['itskingriffyall'],
#  ['40', 'disea'],
#  ['80', '125'],
#  ['dontexpectnothing'],
#  ['onscene', 'nycbuildings'],
#  ['erinmariefishy'],
#  ['techniqu'],
#  ['newsdict'],
#  ['reddits'],
#  ['samanthaturne', '19', 'nagaski'],
#  ['17', '3alarm', '2'],
#  ['unfortun'],
#  ['elisagxrcia'],
#  ['121', 'manyvids'],
#  ['summerfate'],
#  ['insanelimits', '400t', '3'],
#  ['2', '20', 'biomarkdarrah', 'mikelaidlaw'],
#  ['radychildrens'],
#  ['17'],
#  ['c130', '1980', 'prebreak'],
#  ['difficultpeople'],
#  ['2015'],
#  ['soudelors'],
#  ['thrillhho'],
#  ['buseys', 'postbattle'],
#  ['ameenshaikh', '3', 'sanjaynirupam', 'sureshprabhu'],
#  ['doctordryadma'],
#  ['9', 'o784', '2', '3946', '14'],
#  ['sevenfigz'],
#  ['iateyourfood'],
#  ['theadvocatemag', 'chicagoarea', 'p2'],
#  ['ladins'],
#  ['1360', '1360'],
#  ['organizationsfluctuations', 'imbalancesare'],
#  ['dugway'],
#  ['crossborder'],
#  ['cwheate'],
#  ['zakbagans', '2'],
#  ['blazingben', 'pattyds', '50', 'gwfrazee', 'joshuaassaraf'],
#  ['shantaeforsmash', 'shantaehalfgeniehero'],
#  ['mottas'],
#  ['goodells'],
#  ['2015'],
#  ['dqsvyusy'],
#  ['agalloch'],
#  ['teamtwiistz'],
#  ['worseits'],
#  ['jeremycorbyn', '2', 'owenjones', '84'],
#  ['joegoodmanjr'],
#  ['gatorgmuzik', 'fettilootch', 'slanglucci', 'oppressions'],
#  ['trailheads', 'idfire'],
#  ['3', '2015'],
#  ['commoditiesare', '2008'],
#  ['magner'],
#  ['it۪s', 'can۪t'],
#  ['joshrogin', 'slwsew', '379', 'jimsciutto', 'natseccnn'],
#  ['acousticmaloley'],
#  ['iraq۪s', 'yazidis'],
#  ['18wheeler', '180'],
#  ['5'],
#  ['trustymclusty'],
#  ['1', 'gameplaywalkthrough', '1'],
#  ['apollobrown', 'billdanzemop', 'famemop'],
#  ['13131313', 'otooledalton', 'averywelch', '23', 'otoole', '1055'],
#  ['roadid'],
#  ['udhampur'],
#  ['2', 'r3do'],
#  ['50', 'firenews'],
#  ['pukesmoothie'],
#  ['shakingits'],
#  ['64'],
#  ['thisdayinhistory', '1862'],
#  ['360', '2011'],
#  ['rtamerica', 'rtcom', 'soudelor'],
#  ['soudelor'],
#  ['metrofmtalk'],
#  ['darrylb', '1979', 'thatnot', '2017', '2019'],
#  ['missionhills'],
#  ['crematoria'],
#  ['35', '723', '4193'],
#  ['libertygeek', '83'],
#  ['funnynews'],
#  ['abomb'],
#  ['teahivetweets'],
#  ['europeradio'],
#  ['thecomedyquote', '50shadezofgrey', 'p45perez'],
#  ['uptotheminute', 'iaavroiv'],
#  ['12'],
#  ['5sos'],
#  ['judithabarrow'],
#  ['70'],
#  ['hatcap', 'silvergray'],
#  ['urogyn', 'meshnewsdesk'],
#  ['rebelmage', '2', '4'],
#  ['johncusack', 'abomb', '1946'],
#  ['timmicallef', 'troubleonmymind'],
#  ['soudelor', 'rumblevideo'],
#  ['70'],
#  ['kg4vaal', 'lmaovv', 'babalmaowelcome', 'nyozi', 'kwaaaaadead'],
#  ['duststorm'],
#  ['democracy۪s', 'dawabsha'],
#  ['aredeluged'],
#  ['bioterror', 'newsintweets'],
#  ['1030pm'],
#  ['teamduval', 'terrellt'],
#  ['chistate', '33', 'vandalzing'],
#  ['ariaahrary', 'thetawniest'],
#  ['sapphirescallop', 'haaaaaa'],
#  ['raisinfingers'],
#  ['ultimalucha', 'luchaunderground'],
#  ['optiks', 'onyxfire'],
#  ['wildhorses'],
#  ['mattbez'],
#  ['55', 'extinctionp'],
#  ['i۪ve'],
#  ['sinjar', 'yazidis', 'rapidcity'],
#  ['weekold'],
#  ['skardu'],
#  ['it۪s', 'accidents۪', 'it۪s'],
#  ['ebolatrends'],
#  ['2015'],
#  ['bonesymcbones'],
#  ['i5', 'i5', '43rd'],
#  ['lesleymariiee'],
#  ['barcousky'],
#  ['sanelesstheory'],
#  ['ofnsixjks'],
#  ['dylanmcclure', '55'],
#  ['lisavanderpump'],
#  ['mw3'],
#  ['dailytimesngr'],
#  ['coworkerunaware'],
#  ['70'],
#  ['thomassmonson'],
#  ['viralspell', '4000'],
#  ['southdowns', 'treeporn'],
#  ['woodelijah', 'writerslife'],
#  ['3million'],
#  ['kc5kh', 'mhtw', '4fnet'],
#  ['indiannews'],
#  ['i74', '25', 'crawfordsville'],
#  ['bartonleclay'],
#  ['microlight', 'peritoengrafoscopia'],
#  ['30pcs', '12mm'],
#  ['reddits', 'prebreak'],
#  ['5th', '530730pm', 'wgton', 'tradeinservicesagreement'],
#  ['croydonization', '2011'],
#  ['kanger', 'rvaping', '101'],
#  ['court۪s', '1998'],
#  ['hwrf', '20'],
#  ['modnao', '23'],
#  ['320', 'icemoon', 'djicemoon'],
#  ['zxathetis'],
#  ['19', '5km'],
#  ['2'],
#  ['davidwarner', '31'],
#  ['55432', '1950', 'magnetraction'],
#  ['mistrustful', 'onegreenplanet'],
#  ['cp030'],
#  ['dannyraynard'],
#  ['2'],
#  ['2', '103', '216'],
#  ['fantosex'],
#  ['kmactwn', 'meaganerd'],
#  ['militarydotcom'],
#  ['judemugabi'],
#  ['gangstermail'],
#  ['3'],
#  ['311'],
#  ['69', '250000'],
#  ['carryi'],
#  ['parleys'],
#  ['changelessly'],
#  ['losdelsonido', 'typhoondevastated', 'ivanberroa'],
#  ['40'],
#  ['slikrickdarula'],
#  ['tweetlikeitsseptember', '11th2001'],
#  ['smexaminer'],
#  ['2'],
#  ['alexeivolkov', '1', 'mcfaul', 'roskomnadzor'],
#  ['6', '2015', 'gawlowski'],
#  ['followerofdole'],
#  ['70th'],
#  ['ۼ'],
#  ['thetshirtkid'],
#  ['pmharper'],
#  ['2015', 'weiqin'],
#  ['here۪s'],
#  ['2'],
#  ['daniriot', 'daysweeks'],
#  ['mcgsecure'],
#  ['thewesterngaz'],
#  ['kriszellner', 'triplemania', 'myztiziziziziz'],
#  ['50'],
#  ['otrabaltimore'],
#  ['pickathon', 'sunsetballard', 'tomonakayama'],
#  ['100'],
#  ['rockyfire'],
#  ['jassycurtis'],
#  ['trafficsouthe', 'roadpoleast', 'a27', 'a283'],
#  ['22'],
#  ['swearyg'],
#  ['ziphimup'],
#  ['connectorconnecto', '917032'],
#  ['oooooohhhh'],
#  ['nasahurricane', 'pacifics'],
#  ['sakhalintribune'],
#  ['5', 'galvnews'],
#  ['liveleakfun'],
#  ['pixelsmovie'],
#  ['georgegallagher'],
#  ['laughtraders', '1'],
#  ['gabrielleaplin'],
#  ['briannafrost'],
#  ['publicityalthough'],
#  ['versethe'],
#  ['okgabby'],
#  ['paturnpike', 'patp', 'pa18'],
#  ['54000', 'signatureschange'],
#  ['phantasmal', 'cummerbund'],
#  ['atlwtmgc'],
#  ['teslas'],
#  ['carneross', 'postcapitalism'],
#  ['mckenzieblackw', '1'],
#  ['arobotlegion'],
#  ['fromthedesk', 'muumbo', 'quantumdatainformatics'],
#  ['ahhtheenikki'],
#  ['thda', 'antiblight'],
#  ['portaloos'],
#  ['ingescott'],
#  ['rgj'],
#  ['aliveafter', '5'],
#  ['cjbanning',
#   '4sake',
#   'argsuppose',
#   'preborn',
#   'individl',
#   'rightsgenerally',
#   'courtof'],
#  ['you۪re'],
#  ['neileastwood', '77', 'microlight'],
#  ['momneedscoffee', 'iwontmakeit'],
#  ['garbanzobean', '23'],
#  ['528'],
#  ['localarsonist', 'cloudygoldrush'],
#  ['shantaeskyy', '2', 'wheavenly'],
#  ['20'],
#  ['coreyashe'],
#  ['cortezera'],
#  ['boomerangtime', 'rskarim', '1', 'sopameer', 'wattashit', '3'],
#  ['marstu', '67', 'benefitsgreat', 'foodfree'],
#  ['19', '5km', '2015080', '6', '010401', '2015080', '5', '150401', '1000'],
#  ['trjdavis'],
#  ['12000'],
#  ['1100', '1800', '86'],
#  ['13', 'lulgzimbestpicts'],
#  ['2'],
#  ['5'],
#  ['bestnaijamade', '16yr', 'bestnaijamade', 'bestnaijamade', 'bestnaijamade'],
#  ['4month', 'kontagora'],
#  ['405', 'niagaravehicles'],
#  ['securedgt'],
#  ['2014'],
#  ['updateme', '2', '91', 'jeffersonampdoris', 'sherfield', '72'],
#  ['batfanuk'],
#  ['cameronsurname', 'chrisg', '0000', '1'],
#  ['organicallyrude', '1rockstar62'],
#  ['papiichampoo'],
#  ['6'],
#  ['115film', 'unstablethe'],
#  ['shadowflame'],
#  ['toshikazukatayama', 'reportonlyquakenews', 'earthquakereport'],
#  ['05', 'youheat', '5۪', 'deejayempiresound'],
#  ['hazzel'],
#  ['calgarysun'],
#  ['funtenna', '2015', 'prebreak'],
#  ['4'],
#  ['16yr'],
#  ['ebrointheam',
#   'jaybig',
#   'lpunbiggiewrap',
#   'overzero',
#   'questionfatalityflawless'],
#  ['19', 'dorret'],
#  ['exceptional۪', '11', '95', 'droughtgov'],
#  ['6beyonce'],
#  ['adanne'],
#  ['picthis', 'i۪m'],
#  ['zachlowenba', 'inundation'],
#  ['lindenow', '315pm'],
#  ['7', '2015', 'transcendblazing'],
#  ['mh370'],
#  ['speedtech', '544'],
#  ['envyseven', 'queenmy', 'overturesplease', 'songfor'],
#  ['05', '435pm', 'wxky'],
#  ['neelum', 'muzaffarabad'],
#  ['movietheatre', '615'],
#  ['roadwayproperty', '15901'],
#  ['soapscoop'],
#  ['caaaaaall'],
#  ['4000008000', '00'],
#  ['m194', '5km', '8615', '10401'],
#  ['njdotcom'],
#  ['notleys', 'albertas'],
#  ['180'],
#  ['concertaugust', '20', '20152'],
#  ['pickerel', 'reidlake'],
#  ['strikesstrikes'],
#  ['jeesss', '7', '911'],
#  ['kelworldpeace', 'taxstone'],
#  ['michaelgbaron', '184'],
#  ['3'],
#  ['911'],
#  ['katunews'],
#  ['gamergate'],
#  ['luxuryhomes'],
#  ['suzes', 'loccitane'],
#  ['jetsetextra', 'a2', 'jsett'],
#  ['anthxvy'],
#  ['44', 'takeshimas'],
#  ['8'],
#  ['300k'],
#  ['michaelwestbiz'],
#  ['doublecups', 'trubgme', 'thisizbwright'],
#  ['163163millions'],
#  ['fukushimatepco'],
#  ['erpestar', 'popobawa'],
#  ['2613', '911', '1008pla'],
#  ['kerricktrial', 'twcnewsclt'],
#  ['1030', '60', 'myswc'],
#  ['1978'],
#  ['remedyyyy'],
#  ['bc19'],
#  ['yelllowheather'],
#  ['mtvsummerstar', 'videoveranomtv'],
#  ['2'],
#  ['m194', '0104', '5km'],
#  ['11'],
#  ['ntsouthwest'],
#  ['meatloving', 'owenharris', '82'],
#  ['pamelamueller', 'privlege'],
#  ['chillimik', 'hushlegs'],
#  ['i77'],
#  ['ۢ'],
#  ['thomasistrash', 'thomasistrash'],
#  ['crematoria'],
#  ['china۪s'],
#  ['magicallester'],
#  ['sittwe', 'ihhen'],
#  ['wsvr', '1686b', 'vhull', 'eurostyle'],
#  ['angstattack'],
#  ['baeffee', 'randompelar'],
#  ['16yr'],
#  ['2907201', '5', 'watchthevideo'],
#  ['coleenlisa'],
#  ['livingsafely'],
#  ['joshlado'],
#  ['leoblakecarter'],
#  ['raabchar', '28', 'morganlawgrp', 'selfinflict'],
#  ['3acre', 'slownewsday'],
#  ['fewmoretweets'],
#  ['02', '4'],
#  ['sirbrandonknt', 'lesnarcena'],
#  ['disembarkment', 'tconnellyr'],
#  ['08', '5'],
#  ['shekhargupta', 'mihirssharma', 'adsit'],
#  ['345pm'],
#  ['summerfate', 'mikeparractor', 'misscharleywebb'],
#  ['tcotccot'],
#  ['hhbu'],
#  ['runnerjoy'],
#  ['2006'],
#  ['370'],
#  ['whelen', '295ss100'],
#  ['srajapakse'],
#  ['saltriverwildhorses'],
#  ['ohhmyjoshh', 'stevenrulles'],
#  ['830pm', 'gtgtgt'],
#  ['careerbest', '8'],
#  ['citymapper'],
#  ['cvinchwaow'],
#  ['emergencyresponse'],
#  ['marginoferror'],
#  ['60', 'lt75', '715'],
#  ['walerga'],
#  ['abbruchsimulator'],
#  ['deosl', '86', 'xaviermarquis'],
#  ['sinjar', '40pg', 'movt', 'yazidi', '2'],
#  ['22'],
#  ['sharpino', '1990', 'pok̩mon', '05', '064'],
#  ['propertycasualty', '1', 'propertycasu'],
#  ['107'],
#  ['vagersedolla'],
#  ['teambarrowman'],
#  ['bioterror'],
#  ['stampedes', 'beingauthor'],
#  ['don۪t'],
#  ['ch4', 'x37bs', '66m'],
#  ['comdev'],
#  ['capeann', 'triciaoneill', 'triciaoneillphoto'],
#  ['whiteterrorism'],
#  ['9', 'o784', '3', '3941', '13'],
#  ['piprhys'],
#  ['steviede', '83', 'roathboy', 'badgeofhonour'],
#  ['marketingmediocrity'],
#  ['abandonedpics', 'abbandoned', 'that۪s', 'darsena', 'scaligero', 'sirmione'],
#  ['collideworship'],
#  ['writersshe', 'overextant'],
#  ['michelleellle'],
#  ['plsss', '16yr'],
#  ['ineedexposure'],
#  ['2014', 'crqck', 'becyme'],
#  ['seanpeconi', 'jasonfloyd', 'lynchonsports', 'criscyborg'],
#  ['19', '15km', '2015080', '6', '001116', '2015080', '5', '161116', '080'],
#  ['patrickandsam', 'ghaccount'],
#  ['schwarber'],
#  ['spongea'],
#  ['retrofitting', 'fukushimaactu'],
#  ['drbaseball', '41', 'granttamane', '8', 'drewwtaylor', '77', '4'],
#  ['reddakushgodd'],
#  ['varagesale', 'candacedx'],
#  ['5sos', 'scasualty'],
#  ['r̩union', '370'],
#  ['funnydadcoach'],
#  ['listenpurchase'],
#  ['1'],
#  ['selfimage'],
#  ['runjewels'],
#  ['9'],
#  ['smoakqueen'],
#  ['detkenlang'],
#  ['argentings', 'aaaaaaallll', 'i۪m', 'i۪m'],
#  ['politifiact', '30'],
#  ['detroitpls'],
#  ['3'],
#  ['3inspired'],
#  ['gnwt', 'pickerel'],
#  ['3alarm', 'nh1news'],
#  ['13', '1km', '2015080', '5', '234021', '2015080', '5', '164021', '0700'],
#  ['waimate'],
#  ['1330'],
#  ['mh370'],
#  ['explosivesrigged'],
#  ['cainsuch'],
#  ['bioter'],
#  ['shop۪s', 'cutekitten', 'summerinsweden', 'katterp̴instagram', 'dumle'],
#  ['50'],
#  ['gracemccreave',
#   'jamisonevann',
#   'jaceswain',
#   'laneyslife',
#   'jacksonlaurie',
#   '1'],
#  ['flavorchargedtea'],
#  ['dorrets'],
#  ['meatloving'],
#  ['tetovo'],
#  ['canaanites'],
#  ['12000'],
#  ['fevwarrior'],
#  ['i77'],
#  ['brodyfrieling', 'hannabrooksie'],
#  ['2'],
#  ['midsouth'],
#  ['perknas', 'praamius', 'dievas'],
#  ['10', '2'],
#  ['sinjar', 'yazidi', 'yazidishingalgenocide', 'ezidigenocide'],
#  ['viralspell'],
#  ['waterresistant'],
#  ['danielkemp', '6', '39'],
#  ['blackinamerica', 'growingupblack'],
#  ['1775'],
#  ['tcgreno'],
#  ['1141'],
#  ['60'],
#  ['mediterran'],
#  ['typhoondevastated'],
#  ['windmy'],
#  ['4success', '70'],
#  ['rlyeh'],
#  ['teamhendrick', 'teamhendrick', 'ririnsider', 'neanea', '2724'],
#  ['2'],
#  ['ameenshaikh', '3', 'sureshpprabhu'],
#  ['3'],
#  ['demolitiondodging'],
#  ['20'],
#  ['whomikejoness'],
#  ['kurtschlichter', '1'],
#  ['disasterhiroshima'],
#  ['70', '140000', 'ww2'],
#  ['2young'],
#  ['redcoatjackpot'],
#  ['savebees'],
#  ['s3xleak', 'ph0tos', '19yrs', 'ashwo', '0sed', '5'],
#  ['chriscesq', 'bigtent', 'hailstormwindstorm'],
#  ['it۪s'],
#  ['inundation'],
#  ['camplogistics'],
#  ['bluehand'],
#  ['katramsland'],
#  ['typhoondevastated'],
#  ['55433', '1954', 'magnetraction'],
#  ['3', 'kindlecountdown', 'mfrwauthor', 'mgtab'],
#  ['5', '45'],
#  ['ganseyman', 'rt4amention'],
#  ['typhoondevastated'],
#  ['oculusrift', 'virtualreality'],
#  ['thedayct'],
#  ['3', '3', 'demonstratio'],
#  ['5'],
#  ['mothernaturenetwork', 'seattle۪s', 'demolitiondodging', 'up۪'],
#  ['raynbowaffair', 'diamondkesawn', '7', 'ramag'],
#  ['internallydisplaced'],
#  ['daughterofnai', 'yukis'],
#  ['cops۪'],
#  ['abbyairshow'],
#  ['kumailn', 'irongiant'],
#  ['onlinecommunities', 'amageddon'],
#  ['29', '2015'],
#  ['socialnews'],
#  ['soudelor', 'soudelor'],
#  ['xoxoxxxooo', 'rutinaofficial', 'nbchannibal'],
#  ['cubstalk'],
#  ['15'],
#  ['scaryeven'],
#  ['c130', '1980'],
#  ['9', 'zakbagans'],
#  ['5newsdc'],
#  ['lifethreatening', '18wheeler'],
#  ['planetx', 'jaysen'],
#  ['100', '1', 'linerless'],
#  ['05', '710pm', '05', '800pm'],
#  ['lenngonewin'],
#  ['85v265v', '10w'],
#  ['crosssectarian', 'withdrawur'],
#  ['2015', 'san۪a'],
#  ['ferguson۪s'],
#  ['pixeljanosz', 'angelheartnight'],
#  ['thatpersianguy', 'youngsafe'],
#  ['ayyy'],
#  ['messeymetoo'],
#  ['24'],
#  ['x1411'],
#  ['whitbourne'],
#  ['75'],
#  ['10mm', 'etsymntt', 'handmadejewelry'],
#  ['4', 'v452', '6'],
#  ['myanmars', 'lowlying'],
#  ['600'],
#  ['barbitwins', 'helphorses', '23'],
#  ['sonofbobbob', 'shimmyfab', 'trickxie'],
#  ['5'],
#  ['25'],
#  ['dirktrossen', 'snowstormhailstorm'],
#  ['mageavexis'],
#  ['winningwhit'],
#  ['itsqueenbaby'],
#  ['lukebox'],
#  ['1945', 'atomicbomb'],
#  ['4tiles', 'zacb', '10'],
#  ['14th'],
#  ['we۪ll', 'portgassdk'],
#  ['xshanemichaelsx', 'instaxbooty', 'johnnyxphixxle'],
#  ['1'],
#  ['lucypalladino'],
#  ['rtcom', 'accountability۪'],
#  ['i15', 'sr91', 'i15', 'sr91', 'collisionunkn'],
#  ['vivigraubard', 'shortsideness'],
#  ['weatherstay'],
#  ['polishedstone'],
#  ['diyala'],
#  ['navista', '7', 'tinderbox', '24680'],
#  ['17000'],
#  ['tilnow'],
#  ['that۪s'],
#  ['bbsnews', '4'],
#  ['ultimalucha', 'luchaunderground', 'elreynetwork'],
#  ['canonusaimaging',
#   'canonbringit',
#   'canontattoo',
#   'theresmorewherethatcamefrom'],
#  ['tonight۪s'],
#  ['gyrsi'],
#  ['myrtlegroggins', 'ltgaspgt'],
#  ['6th', '1945', 'boyampcarried', '12'],
#  ['8'],
#  ['china۪s'],
#  ['humblethepoet'],
#  ['jrlallo', 'db5'],
#  ['bbcmtd'],
#  ['malaysias', 'mh370'],
#  ['bioterrorism', 'atlasobscura'],
#  ['mh370'],
#  ['13', '10'],
#  ['mp3'],
#  ['thugiauren'],
#  ['chxrmingprince', 'jonesluna'],
#  ['deathholy', 'molys'],
#  ['gorpuazikinak'],
#  ['countynews'],
#  ['05', '912pm', '05', '945pm'],
#  ['rconspiracy'],
#  ['girlthatsrio'],
#  ['longshipdriver'],
#  ['fantasticfourfant', '4sticwhatever'],
#  ['icelandreview', 'icelandreview'],
#  ['37yearold'],
#  ['colnharun'],
#  ['indiatoday', 'iamtssudhir', 'nationfirst'],
#  ['joanns'],
#  ['stiiilo'],
#  ['ashrafiyah'],
#  ['26', '12', 'cedarglade', '2015'],
#  ['noonancindynoonanheartbreak', 'yahistorical', 'undergroundrailraod'],
#  ['emilymcfcheslop', 'pilloried'],
#  ['sanitised', 'hiroshimas', '70'],
#  ['2', '103', '103', 'rowaa'],
#  ['vzwsupport'],
#  ['whatstheimportantvideo'],
#  ['bradohearne'],
#  ['beforeitsnews'],
#  ['35', '21', 'californiaand', 'droughtthis'],
#  ['25', '50'],
#  ['he۪s', 'sippin۪'],
#  ['5sos'],
#  ['mh370'],
#  ['wheelsio', 'hawkhis', 'beltmr'],
#  ['chelsearosette'],
#  ['dramaallama', 'lilourry'],
#  ['hjudeboudreaux'],
#  ['terrorismturn', 'ampveterans', '4', '2'],
#  ['100', '300'],
#  ['36chambers'],
#  ['400', '68', '87', '61'],
#  ['sigalert', '3n133', '5'],
#  ['gidiexclusixe', 'faceless۪', 'bennycapricon'],
#  ['bioterror'],
#  ['grupdates', '16yr'],
#  ['yahootv'],
#  ['anellatulip'],
#  ['megaquake'],
#  ['4'],
#  ['sidelinesavage'],
#  ['youssefyamani'],
#  ['nervana', '1', 'janaq', '30', 'janaq'],
#  ['selfinflicted'],
#  ['ivoices'],
#  ['threatconnect', 'threatintel'],
#  ['19', '15km', '0011'],
#  ['ellaemusic'],
#  ['dampd'],
#  ['midsouth'],
#  ['abbswinston', '15'],
#  ['70th'],
#  ['hideokojimaen', 'amazingsept', '1st'],
#  ['5'],
#  ['papcrdoll', 's2g'],
#  ['votejkt', '48id', '12news', '3', '90th'],
#  ['personalinjury', 'otleyhour'],
#  ['50'],
#  ['72925', 'subsecretariat', '42'],
#  ['bioterror', 'watchcbs', '19'],
#  ['dyannbridges', 'yeshayad', 'claytonbryant', 'artistsunited'],
#  ['2009'],
#  ['26'],
#  ['yiayplan', 'amiibos'],
#  ['wattys', '2015', 'teenfiction'],
#  ['brrookkllyynnr'],
#  ['1'],
#  ['danagould', 'waynesteratl'],
#  ['mh370'],
#  ['12'],
#  ['wqow', '18'],
#  ['yahoocare'],
#  ['massmurderer', 'syvret', 'gojamiam'],
#  ['oldtimey'],
#  ['tonedidit'],
#  ['tullamarine'],
#  ['5', '1620', 'hundredodd'],
#  ['firedamn'],
#  ['eggalie'],
#  ['53inch', '300w', '4x4'],
#  ['lm۪s', 'frauncestavern', 'nygovcuomo'],
#  ['mwcahill', '5', 'mcutchen'],
#  ['arovolturi', '3000'],
#  ['homukami'],
#  ['alexandbondarev',
#   'nickcannon',
#   'listenbuy',
#   'realmandyrain',
#   'itunesmusic',
#   'blowmandyup'],
#  ['beatb', '2', '35', '852015', '652', '15000270364'],
#  ['mmchale', '13'],
#  ['gt50'],
#  ['1pack', '2pack', '3pack', 'fleek'],
#  ['sr37', '1141'],
#  ['chamberedblood', 'speakingfromexperience'],
#  ['puzzledtriangle'],
#  ['133', '5', '133', '1070'],
#  ['14'],
#  ['4'],
#  ['34'],
#  ['50k'],
#  ['canberras'],
#  ['surfspa'],
#  ['alexxpage'],
#  ['samesex'],
#  ['1'],
#  ['ng2x5', 'mhtw', '4fnet', 'memebaiting', 'foxsportscom'],
#  ['hailzel'],
#  ['yourboyshawn'],
#  ['37592'],
#  ['laurae', '303b', 'sheilagunnreid', '2500', 'yezidi', 'slaveswe'],
#  ['enzasbargains', 'a5', 'profittothepeople'],
#  ['begforcum',
#   'alldaycumshots',
#   'sexycumshots',
#   'cumtown',
#   'bjnutt',
#   '2',
#   'girlslovecum'],
#  ['emhub'],
#  ['dinallyhot', 'harmkid'],
#  ['nigeltanner', '1'],
#  ['inroicesmake'],
#  ['abbswinston'],
#  ['2010'],
#  ['20', 'popularmmos'],
#  ['johnboywest'],
#  ['hungerarticles'],
#  ['heavyrain'],
#  ['pyrbliss'],
#  ['grief۪'],
#  ['ageekyfangirl', '14', '1', '2', '3'],
#  ['0epiphany', '5'],
#  ['2907201', '5', 'can۪t'],
#  ['michelebachman'],
#  ['humaza'],
#  ['jamaicaobserver', 'cnewslive'],
#  ['4kus',
#   '15moferadio',
#   'heavybag',
#   '201',
#   'battledom',
#   'qotring',
#   'battlerapchris',
#   '1128'],
#  ['misogynyracismreligionfueled'],
#  ['firefightr', '12hr', 'lookg', '4'],
#  ['wiwnpfxa'],
#  ['sandrabland'],
#  ['spicybreads', 'coxytown'],
#  ['mathewisangry', 'z3kesk1', 'saladinahmed'],
#  ['2us'],
#  ['2a'],
#  ['falloffcliff'],
#  ['sergiopiaggio', 'i۪d', 'wasn۪t'],
#  ['2016'],
#  ['udhampuragain', '2', 'udhampur'],
#  ['khadidon'],
#  ['70'],
#  ['50'],
#  ['thehighfessions', 'blastedi'],
#  ['fuelgas', 'tahoeblazeravalanches', '10'],
#  ['essenceofme'],
#  ['05', '844pm', '05', '915pm'],
#  ['localarsonist'],
#  ['43', 'dolakha', '367'],
#  ['bioterror'],
#  ['tomdean', '86', 'hazardwillian'],
#  ['13'],
#  ['justmarried', '4000'],
#  ['djjohnblaze', 'sothwest'],
#  ['ielectrocute'],
#  ['5007', 'cantmakeitup'],
#  ['withannihilation'],
#  ['10'],
#  ['roughdeal', '1', 'hudhud', 'chandrababu'],
#  ['3'],
#  ['70th'],
#  ['justinfenton', 'monumentalized'],
#  ['laylovetournay', 'ryrotheunaware'],
#  ['60', '20', 'i15', 'idwx'],
#  ['18'],
#  ['tisas', 'tristapnwfdn'],
#  ['mh370', 'mh370'],
#  ['7'],
#  ['erdogans', '20', '31', 'surṳ'],
#  ['mipasho'],
#  ['jetengine', 'turbojet', 'g90'],
#  ['canagal'],
#  ['3h', '2008'],
#  ['canaanites', 'worldnetdaily'],
#  ['2015', 'womengirls'],
#  ['bkanioros'],
#  ['awickedassassin'],
#  ['ianhellfire', 'fadc'],
#  ['raidersreporter', '957thegame'],
#  ['grief۪'],
#  ['wcbd'],
#  ['4is', '48hours'],
#  ['crematoria'],
#  ['kdunning', '1919', 'hsnowberger', 'gabrielasmith', '29', '16'],
#  ['josephjett'],
#  ['cpinto', '001'],
#  ['mh370', 'scmpnews'],
#  ['annmarieronan', 'niamhosullivanx'],
#  ['24'],
#  ['1', 'iclowns', '2iclown'],
#  ['diegt'],
#  ['411', '4', 'policerun'],
#  ['davidhurn', 'tokteacher'],
#  ['darkreading'],
#  ['devpeace'],
#  ['funkflex'],
#  ['facephotos'],
#  ['decadelong', 'billiondollar', 'harperslegacy'],
#  ['naturaldisasters'],
#  ['blizzheroes', 'dustinbrowder', 'lt3'],
#  ['5', '3', '103'],
#  ['1lla'],
#  ['teamhennessy', 'tprimo', '24', '1', 'djeddygnj'],
#  ['15'],
#  ['gregorysanders', 'usdot'],
#  ['ianhellfire'],
#  ['shakjn', 'c7'],
#  ['ibliz', '140'],
#  ['mikeparractor', 'summerfate'],
#  ['footballfreestyle', '247'],
#  ['60'],
#  ['58200'],
#  ['7amdollela', '3la', '7aal'],
#  ['firefigthers'],
#  ['15'],
#  ['graysondolan'],
#  ['sixmeter'],
#  ['liveworkshop'],
#  ['soothmyslumber', 'watermeloann', 'populardemand', 'thewebbeffect', '19'],
#  ['princeoffencing'],
#  ['hammondville', '7news'],
#  ['sunofgod'],
#  ['whyyyy'],
#  ['pahandabear', 'nethaera'],
#  ['mattmosley'],
#  ['benaffleck', 'mraffleck'],
#  ['5', '2'],
#  ['eudrylantiqua', '33', 'eudrylantiqua'],
#  ['safyuan'],
#  ['15', '120v', '14', '1800w'],
#  ['jet۪s', 'r̩union'],
#  ['84'],
#  ['battleroyalemod', '26'],
#  ['moorlandschmbr'],
#  ['asianshawtyy'],
#  ['cwhoops'],
#  ['mrbrianorl'],
#  ['trollkrattos', '100000'],
#  ['martinbarrow'],
#  ['9503', '528', '530', '540', '740', '2017770', '7d'],
#  ['geekapocalypse', '4pm', '2', '9', 'etcpb'],
#  ['sgtmaj', '28', 'maghar', '361', '13'],
#  ['14028', '8'],
#  ['rymathieson'],
#  ['80pcs', '55x1'],
#  ['hoshin', '7'],
#  ['kcem', '3', 'sr14'],
#  ['3', '1915kaiserjaegers'],
#  ['95'],
#  ['mh370', 'ministersays'],
#  ['afterhaiyan', 'disasterrecovery'],
#  ['x1415'],
#  ['doylech'],
#  ['chicagoarea'],
#  ['alexbelloli'],
#  ['psychrewatch'],
#  ['05082015'],
#  ['63rdprairie'],
#  ['you۪re', 'you۪re'],
#  ['famping', 'mishacollins'],
#  ['sinjar', 'yazidis'],
#  ['koscielnyfc'],
#  ['westmdcountypa', '20th'],
#  ['melrises', '1969', 'wwwbigbaldhead', 'jessienojoke', 'melissaross', '9847'],
#  ['3', 'loupascale'],
#  ['23', '752'],
#  ['0', 'i80'],
#  ['14', 'let۪s'],
#  ['2016'],
#  ['daisycuttertz', 'grogparty', 'tonyburke'],
#  ['viennabutcher'],
#  ['megadethsymphony'],
#  ['group۪s'],
#  ['makinmemories', '2015'],
#  ['3'],
#  ['destinythegame'],
#  ['9000'],
#  ['2015'],
#  ['housesbuildings'],
#  ['previouslyondoyintv', 'makinwa۪s'],
#  ['sensorsenso', '0206', '20ll4'],
#  ['nflexpertpicks'],
#  ['widouglass', 'kurrrlyw', 'adamrubinespn'],
#  ['hazardu'],
#  ['newsbeatsocial'],
#  ['5sostag'],
#  ['37'],
#  ['2009'],
#  ['ayekoradio', 'brasswork'],
#  ['3', '12'],
#  ['therealrittz', 'fettilootch', 'slanglucci', 'oppressions'],
#  ['rebahes', 'zenandemcfen', 'ndzedze', '2ashes'],
#  ['930pm'],
#  ['weloverobdyrdek', 'adrianpeel'],
#  ['karasuno'],
#  ['nonhazardous', '1916'],
#  ['dustpiggies', 'dustpig'],
#  ['teamatowinner'],
#  ['mh370'],
#  ['70'],
#  ['627', '16'],
#  ['phmsa'],
#  ['642498', 'nowlike', 'usthe'],
#  ['kinkyconnors'],
#  ['1'],
#  ['thebrooklynlife'],
#  ['0nking0201', 'screamsdont', 'animatronics'],
#  ['034', '8p', '21a', '5', '5s', '5c', '6', '6'],
#  ['japn', '063243', '0'],
#  ['55436', '1950', 'magnetraction'],
#  ['dorling', 'kindersley'],
#  ['oklahomaok', '1030'],
#  ['wdsu', 'wdsu'],
#  ['kasabwe'],
#  ['7'],
#  ['kaiseiw'],
#  ['stavola', 'lhmovie'],
#  ['3d', 'soudelor', 'nasahurricane'],
#  ['techerit'],
#  ['peopleforestswildlifewater'],
#  ['ladytraining'],
#  ['rworldnews'],
#  ['edwelchmusic'],
#  ['threat۪'],
#  ['1', '5', '816'],
#  ['1', 'windwakerstyle'],
#  ['100'],
#  ['11000', '30'],
#  ['troylercraft'],
#  ['calgaryweather', 'yycweather'],
#  ['446', '2nd', '2523'],
#  ['rexyy'],
#  ['bosphore'],
#  ['wrongsuddenly', 'anoderdid'],
#  ['somethingyr'],
#  ['olliebailey', '11'],
#  ['can۪t'],
#  ['rtrrtcoach', '911', '1008planet'],
#  ['05', '829pm', '05', '915pm'],
#  ['60000', '12000'],
#  ['forbesasia'],
#  ['mh370'],
#  ['1'],
#  ['wsls', 'jennasjems', 'patrickwsls'],
#  ['bakeofffriends'],
#  ['bidtime'],
#  ['reddits'],
#  ['airhorns'],
#  ['timedoes'],
#  ['preston۪s'],
#  ['higuains'],
#  ['tyuler', '58', 'injuriesthat', 'uiseful'],
#  ['razedonit', 'honeystaysuper', '51'],
#  ['ellenfromnowon', '7speed', '9'],
#  ['ruddyyyyyy', 'jamiegriff', '97'],
#  ['complexmag'],
#  ['blackhatwriter'],
#  ['ninahoag'],
#  ['lonewolffur'],
#  ['turnedonfetaboo', 'hsjb', '215', 'claytonbryant', 'artistsunited'],
#  ['parley۪s'],
#  ['daorcey', 'graywardens'],
#  ['apartmentloan', 'badcredit'],
#  ['cbccalgary', 'underpasses'],
#  ['2014', 'rottentomatoes'],
#  ['profithungry', 'savebees'],
#  ['15', 'esquireattire'],
#  ['ebolacase'],
#  ['f16'],
#  ['novalismi', 'mallord', '1843'],
#  ['fcsl'],
#  ['40'],
#  ['30'],
#  ['tankerfire'],
#  ['4000', '3'],
#  ['600', '600'],
#  ['coachkeith', '44', 'hannomottola', 'trpreston', '01', 'mlrydalch'],
#  ['createdunique', '23', 'kerenserpa', 'arianareed', '11'],
#  ['tkyonly', '1fmk'],
#  ['1138am', '1154am'],
#  ['akinwunmiambode', 'urgentthere', '3', 'bstop', 'oworoshoki'],
#  ['spacewolverine'],
#  ['abbswinston', '18'],
#  ['soudelor', 'generalnews'],
#  ['erker'],
#  ['crematoria'],
#  ['f496d', 'mhtw', '4fnet'],
#  ['int۪l'],
#  ['grantfactory', 'seawalls'],
#  ['singlecar'],
#  ['torontorc'],
#  ['hermancranston'],
#  ['nikkihaley'],
#  ['body۪s', 'ۢ'],
#  ['2907201', '5'],
#  ['huffpostalberta', 'harperblamesalbertans'],
#  ['4'],
#  ['15'],
#  ['america۪s', 'pletch۪s'],
#  ['typhoondevastated'],
#  ['3rd', 'fieldwide'],
#  ['2', '1'],
#  ['bishoyragheb', 'bioterrorism'],
#  ['101'],
#  ['freiza'],
#  ['tonyakappes', '11'],
#  ['bb4sp'],
#  ['nonpower', '5'],
#  ['losangelestimes'],
#  ['malikchaimaa'],
#  ['94kyle'],
#  ['8minute', 'fatburning', 'that۪s', 'fatburning', 'burnfat'],
#  ['080215', '12000'],
#  ['515p', 'tmake', 'bhome', '7p'],
#  ['reprocussions'],
#  ['5', 'pmngiqy'],
#  ['wonderousallure', 'hhello'],
#  ['24'],
#  ['3'],
#  ['eightynine'],
#  ['3340'],
#  ['followtheblonde'],
#  ['progessive'],
#  ['multidimen'],
#  ['slashandburn'],
#  ['leandotorg'],
#  ['ltdalius'],
#  ['no2'],
#  ['katunews', 'sr14', '1700', '2'],
#  ['whistlerblckcmb', 'snowbacksunday', '26', '2015', 'momentumcamps'],
#  ['3'],
#  ['16', 'pt1'],
#  ['soudelor'],
#  ['0'],
#  ['ra̼l'],
#  ['fuckkkkkk'],
#  ['bioterror'],
#  ['pkadlik', 'jojowizphilipp', 'viptickets', 'imgunnashakeitallnight'],
#  ['peytonlaynec'],
#  ['univsfoundation', '731'],
#  ['jackisheaffer'],
#  ['i580', 'i580', 'collisionno'],
#  ['servicin'],
#  ['damnaarielle'],
#  ['charlieputh'],
#  ['150', 'nonsrank'],
#  ['sigalert', '133', '133', '5', '1070'],
#  ['editaxohaze'],
#  ['sensorknock', 'as10004'],
#  ['splifs'],
#  ['breakingnewslh', 'breemars', 'cnns'],
#  ['6'],
#  ['strategicpatience'],
#  ['hnlnow'],
#  ['wolfgangjoc'],
#  ['toxicsavior'],
#  ['birdyword', 'sunkcost'],
#  ['bioterror'],
#  ['mh370'],
#  ['10', 'lanparty'],
#  ['b5'],
#  ['sometimesi'],
#  ['lemairelee', 'danharmon', '140'],
#  ['20k'],
#  ['30'],
#  ['3'],
#  ['crushit', 'experiencesmh'],
#  ['25'],
#  ['unitednyblogs', 'insidecityhall', 'nyclass', 'nyclass', '500k'],
#  ['0day'],
#  ['luzukokoti'],
#  ['16yr'],
#  ['19000', 'opengaza'],
#  ['warlordqueen'],
#  ['weaponxmusic'],
#  ['senfeinstein'],
#  ['muaytai', 'wantmyabsback'],
#  ['soudelor', '7', '2', '7chicago'],
#  ['myvintagesoul'],
#  ['carlilescanoelivery'],
#  ['367', '25'],
#  ['interestingwhy', 'canaanites', 'worldnetdaily'],
#  ['blizzarddraco', 'lonewolffur'],
#  ['zonewolf', '123', '20'],
#  ['4'],
#  ['kiwikaryn'],
#  ['bb17'],
#  ['themagickidraps'],
#  ['beachis'],
#  ['blainescronuts'],
#  ['sebastianstanisaliveandwell'],
#  ['don۪t', 'let۪s'],
#  ['daniglasgow', '45'],
#  ['bruminthecity'],
#  ['tractortrailers', '42'],
#  ['selfimage'],
#  ['itstiimothy', 'bhill'],
#  ['mukilteo', 'q13', 'earthquakenews'],
#  ['alaskas', 'archipelagowolves', '60', '1'],
#  ['14hours'],
#  ['everydaynaija', '60'],
#  ['daretotaha'],
#  ['gtlt'],
#  ['n15b'],
#  ['30', 'newsintweets'],
#  ['7'],
#  ['55'],
#  ['spinningbot', 'standuser'],
#  ['floodmagazine', 'hotchip', 'hotchip', 'greektheatrela'],
#  ['3'],
#  ['22beyonce'],
#  ['joannabomb', 'eventchase', 'weneeda', '5hvmaperformance'],
#  ['uk۪s', '20'],
#  ['fairx', '818x', 'playoverwatch', 'blizzardcs'],
#  ['handside'],
#  ['kopiteluke', '1892'],
#  ['czallstarwes'],
#  ['mzgraciebaby', 'officialrealrap'],
#  ['1000s'],
#  ['timzak', 'kidsbook'],
#  ['peregrinekiwi', 'boymonster', 'cp2020'],
#  ['12000'],
#  ['x1421'],
#  ['12'],
#  ['lzktjnox'],
#  ['inundation'],
#  ['burundis'],
#  ['noncompliant', 'wwwcbplawyers'],
#  ['ladyshaxx'],
#  ['jplocalfirst', 'eliotschool'],
#  ['2nd'],
#  ['sympathyonlf'],
#  ['kallemattsons'],
#  ['530'],
#  ['catastrophicfallenangel', 'reveillertm', 'macabrelolita', 'acids۪'],
#  ['6', '2'],
#  ['wildhorses', 'tantonationalforest'],
#  ['truthfrequencyradio'],
#  ['aljavieera', 'publicsafetyfirst'],
#  ['arsonistmusic'],
#  ['sniiiiiiff'],
#  ['7k', '2', '9newsmornings'],
#  ['09', '2015080', '6', '015025', '2015080', '6', '015025', 'earthtwerk'],
#  ['engineshed'],
#  ['3'],
#  ['kapokekito'],
#  ['blackforestgateau', '2015'],
#  ['jackmulholland', '1'],
#  ['i65', '28'],
#  ['thelegendblue', '23'],
#  ['600', '600', 'damatu'],
#  ['ybtheprophet'],
#  ['1', '60', 'kotaweather'],
#  ['mccainenl'],
#  ['theleadernews'],
#  ['2'],
#  ['co2'],
#  ['willinghearted'],
#  ['slosheriff', '2', '2'],
#  ['udhampur'],
#  ['greenlacey', 'godslove'],
#  ['70th'],
#  ['keampurley'],
#  ['auntiedote', 'rioslade', 'lockewiggins', 'akarb', '74'],
#  ['timesnewsdesk'],
#  ['stagefright'],
#  ['kidsteenagers', 'bombeffects'],
#  ['paulmyerscough', 'institutionalstructural'],
#  ['4'],
#  ['rolandonabeats'],
#  ['48'],
#  ['appreciativeinquiry'],
#  ['70'],
#  ['1', 'wiimington', 'prkng', 'amphave'],
#  ['slopeofhope'],
#  ['kurtschlichter', 'eurpoe'],
#  ['newsintweets'],
#  ['that۪s', 'wildlifeif', 'don۪t'],
#  ['24'],
#  ['disclos'],
#  ['30', '9'],
#  ['bioterrorism'],
#  ['pioneerpress'],
#  ['metrofmtalk'],
#  ['1x1'],
#  ['15'],
#  ['macia۪s'],
#  ['ahamedis', '125', 'dajaal'],
#  ['justgetawayx', 'lpomampm'],
#  ['mikeparractor'],
#  ['19'],
#  ['stephghinojosa'],
#  ['581941',
#   '1941',
#   'kumasian',
#   'torpedoedsunk',
#   '1',
#   '60',
#   '1',
#   'crewlist',
#   'ww2'],
#  ['jsunnews'],
#  ['qtszg', 'mhtw', '4fnet', '15'],
#  ['plsss', '12000'],
#  ['changea', 'cleanpowerplan'],
#  ['i۪ve'],
#  ['traintragedy'],
#  ['pvdrdljvc'],
#  ['21day'],
#  ['4playthursdays', '1716', '18'],
#  ['vancouverisland'],
#  ['drjustinmazur'],
#  ['greeces'],
#  ['westarson'],
#  ['ampautomated', 'netbots'],
#  ['hollywarnexx'],
#  ['petebests', 'dessicated'],
#  ['joshshatsays'],
#  ['northbayhealth', 'multicasualty'],
#  ['100'],
#  ['soudelor', '945hpa', '45ms', '60ms'],
#  ['twovehicle', '7'],
#  ['3', 'tilnow'],
#  ['avalanchesgtgt'],
#  ['159', 'messnermatthew', 'newcity'],
#  ['sigalert', '133', '5', 'detouring'],
#  ['orbette'],
#  ['mockingpanems', 'cuddlesforjen'],
#  ['ushanka'],
#  ['saams', 'olilafont', 'tornadogiveaway'],
#  ['seasonfrom', '9', '11', 'onshit'],
#  ['summerfate'],
#  ['naayf', 'chandanee'],
#  ['darkspawn'],
#  ['girlsgirlsboys'],
#  ['dijk۪'],
#  ['deltachildren'],
#  ['2'],
#  ['2nd'],
#  ['anellatulip', 'magisters'],
#  ['soudelor'],
#  ['canberras', 'currong'],
#  ['arceen'],
#  ['catoinstitute'],
#  ['3422', 'redeemeth'],
#  ['6gaming', 'ps4', '3', '2', 'ps3'],
#  ['you۪ve', '3g'],
#  ['bioterror'],
#  ['5', '2015', '2015'],
#  ['mikeparractor', 'superbactor'],
#  ['6'],
#  ['askceeps', 'colinodonoghue', '1'],
#  ['4', '20', '40'],
#  ['vballplaya', '2296'],
#  ['tobiasellwood', '15'],
#  ['gamergate'],
#  ['ianokavo', '96'],
#  ['8588547', '3'],
#  ['willyt', '126'],
#  ['deflategate'],
#  ['ovoizic', 'baddiemoneysign'],
#  ['prsnvns', 'bioterrorism'],
#  ['1'],
#  ['youngheroesid', '4', 'pantherattack', 'mirnawan', '13', 'zakiakiia'],
#  ['kyee', 'nockthie', 'taungbazar', 'buthidaung', 'kasitaroch', 'vivianunhcr'],
#  ['asterpuppet'],
#  ['fennovoima'],
#  ['usnwsgov', '05', '1038pm'],
#  ['14', '4km', '2015080', '6', '005225', '2015080', '5', '175225', '07'],
#  ['ww2', 'ww2'],
#  ['157', '2015', 'introdesolation'],
#  ['jwalkerlyle',
#   'nickcannon',
#   'listenbuy',
#   'realmandyrain',
#   'itunesmusic',
#   'blowmandyup'],
#  ['uswarcrimes'],
#  ['selfimage'],
#  ['16yearold'],
#  ['2015'],
#  ['29', 'kaimai', 'aatraffic'],
#  ['3am'],
#  ['bigperm', '28', '2005', '4', '124', 'utahgrizz'],
#  ['500', 'frackfreelancs', 'deccgovuk', 'frackfreeeu', 'tarletonsophie'],
#  ['anonchimp'],
#  ['hurricanedolce'],
#  ['udhampur', '2', 'spos'],
#  ['masochisticmage'],
#  ['aldwark', 'nyorks'],
#  ['5sos'],
#  ['enjoltair'],
#  ['481'],
#  ['26rfc'],
#  ['bhusa'],
#  ['elkodaily'],
#  ['shanghai۪s'],
#  ['louisan'],
#  ['2', '67'],
#  ['m42', 'j3', 'j3a', '10'],
#  ['bioterror'],
#  ['maatmhi'],
#  ['queenwendy'],
#  ['fa07af174a71408'],
#  ['fifteenmilehigh'],
#  ['changefortheworse'],
#  ['artisteoftheweekfact', '2coastdjs', 'crystalblaz', 'jiwonle'],
#  ['8'],
#  ['endofus'],
#  ['3'],
#  ['45', '5', '290', 'buroker'],
#  ['3alarm', '3alarm'],
#  ['ashberxo', 'mindmischief'],
#  ['3'],
#  ['sittway'],
#  ['we3fordemocracy', '08'],
#  ['snapharmony', '70'],
#  ['8415'],
#  ['brbrs'],
#  ['fictionsharecropping'],
#  ['15', '2015', '325', '10am'],
#  ['ampstart', 'ampask'],
#  ['becarefulharry'],
#  ['6', 'soudelor', '1100'],
#  ['chrisdyson', '16', 'sorrybutitstrue'],
#  ['19', '5km', '2015080', '6', '010401', '2015080', '5', '150401', '1000'],
#  ['1043'],
#  ['dmerida'],
#  ['4700', '11th', 'pg15000044153', '1700', '911'],
#  ['stankyboy', '88'],
#  ['londonfire', 'hazarddangerous'],
#  ['dwenglish'],
#  ['gregskazphotography', 'rainierarms'],
#  ['925', '6', 'r1354'],
#  ['punkblunts', 'sincerelyevelnn'],
#  ['asgharchohan', '86', 'adilghumro', '30'],
#  ['676', '67676'],
#  ['terrorism۪'],
#  ['40'],
#  ['mlsudders'],
#  ['widowelena', 'stelenaalways'],
#  ['5sosfamupdater'],
#  ['tuffers', 'bbctms', 'engvaus'],
#  ['saadthe', 'kpdied', '27', '2007he', 'kppolice'],
#  ['ibautumn'],
#  ['bamagaga', 'kipmooremusic', '1019'],
#  ['pugwash', '6'],
#  ['ciaramckendry'],
#  ['moganwilson'],
#  ['pcps'],
#  ['littlebitofbass', 'silinski'],
#  ['1880', 'dmpl'],
#  ['39'],
#  ['don۪t', 'let۪s'],
#  ['femalegilgameshs'],
#  ['1', '17', 'wage۪'],
#  ['mtnredneck'],
#  ['pantalonesfuego'],
#  ['irandeal', '150'],
#  ['5', 'hannaph', 'soudelor', '500', '06'],
#  ['azcardinals'],
#  ['1030pm'],
#  ['edcxo'],
#  ['363', 'cstsmith', 'floodrainstorm', '14000', '25'],
#  ['seismicsoftware', '3'],
#  ['joshdaniel', 'mikegiarrusso'],
#  ['4'],
#  ['15'],
#  ['999day'],
#  ['25'],
#  ['70', '1945'],
#  ['whensoever', 'sizygwwf'],
#  ['meyerbjoern', 'thelonevirologi', 'mackayim', 'bioterrorism', '2n'],
#  ['5', '90'],
#  ['dambisa', 'prosyn'],
#  ['hronlinetweets'],
#  ['hiroshimanagasaki'],
#  ['udhampur', '2', 'spos'],
#  ['bioterrorism', 'biolabs', 'biosurveillance'],
#  ['pllolz'],
#  ['stfxuniversity', '731'],
#  ['grief۪'],
#  ['dtom', '2'],
#  ['misocapnist', 'unusualwords'],
#  ['ar15'],
#  ['60000', '80000'],
#  ['bekahw'],
#  ['ۢnigeria', '233liveonline'],
#  ['37', 'jamessnyder', '22'],
#  ['50'],
#  ['todayngr'],
#  ['aoms', 'ibooklove', 'bookboost'],
#  ['0day'],
#  ['100', 'johnkass'],
#  ['s01e09', 'bloodymonday'],
#  ['presssec', '4'],
#  ['gemmahentsch', 'megynkelly', 'dloesch'],
#  ['outnumbering'],
#  ['doczone'],
#  ['faultline'],
#  ['4bb'],
#  ['eeasterling', '2'],
#  ['mechamacgyver'],
#  ['cadfyi', 'damagenhs', '999', 'rdhorndale'],
#  ['concertphotography'],
#  ['daysonly', 'kidsbut'],
#  ['jamienye'],
#  ['explosivespacked', '15'],
#  ['rabidmonkeys', '1'],
#  ['3'],
#  ['scotgov', 'tweetlikekez'],
#  ['janiethekillr'],
#  ['50'],
#  ['6pm'],
#  ['sethalphaeus', '5sos'],
#  ['5'],
#  ['3682', 'd50', '61', '2', '20000'],
#  ['dewatering'],
#  ['wdyouth'],
#  ['apocalpytic'],
#  ['orianaarzola'],
#  ['kneelbot'],
#  ['haydnexists', 'didn۪t'],
#  ['christinartnd'],
#  ['womem', 'mommyisbomb'],
#  ['9'],
#  ['dangerousbeans'],
#  ['robertmeyer', '9', 'peoplegt'],
#  ['i10'],
#  ['2'],
#  ['skanndtyagi'],
#  ['montetjwitter',
#   '11',
#   'audreyp',
#   '77',
#   '797',
#   'darrylbrooks',
#   'elitesportsny',
#   'lopezandthelion',
#   'natsnation'],
#  ['udhampur', 'achedin'],
#  ['hawknancy',
#   'nickcannon',
#   'listenbuy',
#   'realmandyrain',
#   'itunesmusic',
#   'blowmandyup'],
#  ['25'],
#  ['epao', 'marsac', 'inundation'],
#  ['countermoonbat', 'voodooben'],
#  ['evaucation'],
#  ['idkimnotfunny'],
#  ['neanderrebel', 'massmurderer'],
#  ['metrofmtalk'],
#  ['office۪s', 'razedʉ', 'ikpeazu'],
#  ['championsblackfoot'],
#  ['crowtherjohn', 'effiedeans', '97'],
#  ['phillipten'],
#  ['mikeparractor', 'rossbarton'],
#  ['robotlvl', '19', '6615434', 'satoshis', 'robotcoingame', 'freebitcoin'],
#  ['don۪t', 'weren۪t', 'grtvnews'],
#  ['londonfire'],
#  ['mh370'],
#  ['8960'],
#  ['64oz'],
#  ['8nn'],
#  ['70', '70'],
#  ['bluedio', '41'],
#  ['jamesmelville'],
#  ['chaosmagician', '97'],
#  ['jaureguiswisdom'],
#  ['selfimage'],
#  ['24'],
#  ['iembothfo', '1000', '2'],
#  ['szuniverse'],
#  ['m00nf00l', 'summerhallery'],
#  ['susanj', '357', 'allinwithchris'],
#  ['aleshabell', '2', 'wheavenly'],
#  ['freyas'],
#  ['epcotexplorer', 'awesomeeeeeeee'],
#  ['scorpioncbs'],
#  ['gasparc'],
#  ['muslimsterrorism', 'catholicismhomophobia'],
#  ['vassalboro', 'petelmcguire'],
#  ['allergan'],
#  ['mh370'],
#  ['marcoarment', '78'],
#  ['btsprep'],
#  ['12'],
#  ['bickford۪s', 'fugazzi۪s'],
#  ['6', 't4'],
#  ['addictionis'],
#  ['2015'],
#  ['lonepine', '666canberra', 'ww1'],
#  ['chemicalweapons', '20', '2012', '96355'],
#  ['crhedrys', 'nkofoxysiren'],
#  ['rosenbergs'],
#  ['2hours'],
#  ['dontestallworth', 'stevesgoddard'],
#  ['prisonplanet', 'warningwild'],
#  ['lennlen'],
#  ['19', '5km'],
#  ['2pcs', '18w', '4wd'],
#  ['gargron'],
#  ['toooooo'],
#  ['fbody', '95', 'gaymaro'],
#  ['70', 'okinawan', '1965'],
#  ['17'],
#  ['aubilenon', 'markkriegsman'],
#  ['71'],
#  ['worldvision', 'myanmarflood', '300000'],
#  ['east۪s'],
#  ['1970the', '2', 'depreciations', 'cadusd', 'b4federal', 'wlandslide'],
#  ['bioterror'],
#  ['sterlingscott'],
#  ['bo2', 'bo3', 'invahnwetrust'],
#  ['tripledigit', '2013'],
#  ['hashtagteaclub'],
#  ['gisuserpr', 'geotech'],
#  ['nailreal'],
#  ['pbban', '300', 'avysss'],
#  ['unsurprisingstill', 'dismaying'],
#  ['twovehicle', 'whitbourne'],
#  ['hegot'],
#  ['mh370'],
#  ['sixsecondcov'],
#  ['nars۪', 'wave۪', 'emilyschuman'],
#  ['teslas', '23'],
#  ['today۪s'],
#  ['1970s', 'suicidebombing', 'reoccur'],
#  ['34'],
#  ['r5live', 'scraptrident'],
#  ['030811', '41yearold'],
#  ['sophieingle', '01', 'angharadjames', '16'],
#  ['mh370'],
#  ['abubaraa', '1', '13', '13'],
#  ['unfml'],
#  ['lancasteronline'],
#  ['367', '25', 'noagenda', 'mvdint'],
#  ['droughttolerant'],
#  ['kidicalmassdc'],
#  ['78', '4353271148'],
#  ['kdonhoops', 'oldfolkexplainstuff'],
#  ['fotofill'],
#  ['jcenters'],
#  ['2'],
#  ['10'],
#  ['slimebeast'],
#  ['abrancaballero',
#   'nickcannon',
#   'listenbuy',
#   'realmandyrain',
#   'itunesmusic',
#   'blowmandyup'],
#  ['kondobyjaymoni'],
#  ['bioterror'],
#  ['jakeadavis', 'fatalityus'],
#  ['cactusborderlands', '2', 'oocvg'],
#  ['hookier'],
#  ['1030pm'],
#  ['4buffalo', 'guardrails', '50'],
#  ['schwarber'],
#  ['ogbor'],
#  ['5hvzlaradio', 'harmkid'],
#  ['microlight'],
#  ['rachelcaine', 'weatherit'],
#  ['rakestrawjeff'],
#  ['1061thetwister'],
#  ['furiosoxv'],
#  ['sa15t', 'sa15t', '2', '1', '1'],
#  ['biterelated', '1979'],
#  ['besttalkradio'],
#  ['2040'],
#  ['12', 'lovethyfamily'],
#  ['06', '24', '09', '06', '24', '09'],
#  ['yychail'],
#  ['80s'],
#  ['bellalinn'],
#  ['5pm'],
#  ['rokiieee'],
#  ['glink', '30'],
#  ['eyewitnesswv'],
#  ['11'],
#  ['selfimage'],
#  ['titadom'],
#  ['kasiakosek'],
#  ['daviss', 'hopfer', 'deglin', 'vallerand'],
#  ['charnock', 'summerfate'],
#  ['makewaterwork', 'westerncanadadrought'],
#  ['camilacabello', '97'],
#  ['179', 'onduty', '15', '3ʉ'],
#  ['kabarmesir', '58', 'rememberrabaa'],
#  ['kevinbacon'],
#  ['taxreturn', '8'],
#  ['1717', 'chaseingram', 'amandagiroux', '28'],
#  ['16yr', 'ekdar'],
#  ['452', 'knobbootemergency', '5'],
#  ['rahulkanwal'],
#  ['46'],
#  ['165', '200'],
#  ['7'],
#  ['fredolsencruise', 'faroeislands'],
#  ['mopheme', 'vuzuhustle'],
#  ['kiranahmedd'],
#  ['40', 'muhamadjabal'],
#  ['crazyideascollege'],
#  ['invoicesx'],
#  ['1', 'bb17'],
#  ['60', '075'],
#  ['indiannews'],
#  ['csaresu'],
#  ['postexistence', 'brzjc'],
#  ['2a'],
#  ['6', '1100', '06'],
#  ['kindermorgan'],
#  ['badotweet'],
#  ['devinjoslyn'],
#  ['gilmanrocks', '7', '8'],
#  ['22', 'industryinsights', 'mcgsecure'],
#  ['billers'],
#  ['robpulsenews', 'huyovoetripolye', 'ldnrterrorists'],
#  ['greateranglia'],
#  ['31', '541'],
#  ['nicklee', '8', '3'],
#  ['kano۪s'],
#  ['jakartapost'],
#  ['teamstream'],
#  ['stoponesounds', '1079', 'stickynyc', '95roots'],
#  ['i77', '31', '40', '86', '118'],
#  ['i40', '118'],
#  ['peaceloverescue'],
#  ['blaaaaaaa', 'resolutevanity'],
#  ['kimacheson', 'scottwalker'],
#  ['jeannathomas', 'vichardy'],
#  ['3', 'italianalps'],
#  ['3'],
#  ['7986'],
#  ['19th', '17jul2015', '64', 'timesap'],
#  ['siouxland', 'siouxlan'],
#  ['24'],
#  ['50'],
#  ['2014'],
#  ['cogxbox'],
#  ['drdrewhln'],
#  ['4', '2015', 'poconorecord', 'emergencymgtmag'],
#  ['udhampur', '2', 'spos'],
#  ['10', 'drjohanfranzen', 'orchs'],
#  ['17', '90', 'loseit'],
#  ['3', '212', '43'],
#  ['localarsonist', 'diamorfiend'],
#  ['growingupspoiled'],
#  ['mhmmm'],
#  ['172'],
#  ['i۪ve', 'jmcwrites', 'pitchwars'],
#  ['hellfireev', 'jackperu', '1'],
#  ['thetxi', 'gunnersfan', '89'],
#  ['2nd', '2'],
#  ['chiefcg'],
#  ['kaaypaat'],
#  ['22', 'idfire'],
#  ['raptorsbeg', 'goodlookrunning'],
#  ['michellemccann', '2', 'davidwilliamso'],
#  ['amznfavorites'],
#  ['nprfreshair', 'meltdowni'],
#  ['meetkakarotto'],
#  ['daewony', '0406'],
#  ['smusx', '16475'],
#  ['9', 'chesttorso', 'kerricktrial', 'jonathanferrell'],
#  ['mumbailocals', 'lessonforlife', 'marinelines'],
#  ['pfannebeckers'],
#  ['benznibeadel'],
#  ['amyschumer'],
#  ['chaboyyhd', '4'],
#  ['centralupload'],
#  ['17'],
#  ['150', 'kbeastx', 'genisys', '90'],
#  ['halljh', '1720'],
#  ['2'],
#  ['iamdowntown'],
#  ['gameofkittens', 'explodingkittens'],
#  ['15'],
#  ['3', 'durvod'],
#  ['emmychappy', '12'],
#  ['heyot', '6'],
#  ['61st', '2121', 'chicagoscanner'],
#  ['grouponuk'],
#  ['lauradeholanda', '83'],
#  ['cecilthelion', 'gtgtthis'],
#  ['raheelsharif', 'darkstormytidalsea'],
#  ['2014', '2disc'],
#  ['wccorosen', 'corycove'],
#  ['21'],
#  ['deathmule', 'stalag', 'ermac'],
#  ['2'],
#  ['02', '03', '50'],
#  ['laterim', '2k15', 'expertwhiner'],
#  ['blackhaired'],
#  ['bioterrorism', '2002'],
#  ['mileswithtate'],
#  ['samelsamel'],
#  ['350'],
#  ['4', '6', 'leedstraif'],
#  ['astrologian'],
#  ['johndcgow'],
#  ['browserhijacker'],
#  ['browndetonate'],
#  ['dcfd', '3lyc', '36'],
#  ['2'],
#  ['7beyonce'],
#  ['bbcwomanshour'],
#  ['famoushorse'],
#  ['railwayproper'],
#  ['nbcnightlynews', 'mh370', 'billneelynbc'],
#  ['modelbubbles', '2', 'wheavenly'],
#  ['fixingmatch'],
#  ['48', 'tlvfaces', 'tlvfacesauspol'],
#  ['15', 'canadasuicide', '15'],
#  ['i75', '459'],
#  ['hairity', 'spikebot'],
#  ['alipaper', 'keepingtheviginaclean', 'metrofmtalk'],
#  ['vpzedd'],
#  ['12000'],
#  ['heleneyancey', 'godslove'],
#  ['bangmeupguk'],
#  ['ddnewslive', 'nitishkumar', 'arvindkejriwal'],
#  ['toiindia', 'udhampur', '2', 'spos'],
#  ['70', '2', '120000'],
#  ['condenses', 'subtornado'],
#  ['cieistea'],
#  ['slosher', 'splatdown', 'splatling'],
#  ['111020'],
#  ['ltlt', 'resoluteshield'],
#  ['hasn۪t', '2'],
#  ['femnism'],
#  ['kmatakobot'],
#  ['lwilliams', '13'],
#  ['1994', '29'],
#  ['starflamegirl'],
#  ['19', '16'],
#  ['meatloving'],
#  ['thongshudder'],
#  ['tonyabbottmhr'],
#  ['tweetinglew', 'tersestuff', 'notley'],
#  ['2'],
#  ['sbnation'],
#  ['weekold'],
#  ['ps1', 'raredealsuk'],
#  ['400', '21'],
#  ['klarajoelsson', '43c'],
#  ['4'],
#  ['telegraphworld'],
#  ['25'],
#  ['aftershockdelo'],
#  ['redruthuk'],
#  ['freediscountbks', '87'],
#  ['doesn۪t', 'onlyit'],
#  ['ofentsetsie'],
#  ['accidentwho'],
#  ['lightningstrike'],
#  ['x1402'],
#  ['1115'],
#  ['nissannews', '1', '6', '2car', 'a1a'],
#  ['cufi'],
#  ['vickybrush'],
#  ['8'],
#  ['70th'],
#  ['3', 'defensenewscomus', '3', 'subsd'],
#  ['cristianinspire'],
#  ['lisajdavidson', '1', 'nataliealana', '87', 'westendshiv'],
#  ['gramzd'],
#  ['bakeofffriends', 'britishbakeoff'],
#  ['udhampur'],
#  ['geoffrickly'],
#  ['slosher', 'fucboi'],
#  ['5', '2015'],
#  ['wellgrounded', 'fpoj'],
#  ['suffield'],
#  ['unhealthyeat'],
#  ['emmap',
#   '645',
#   'vickygeex',
#   'zakbagans',
#   'nickgroff',
#   'aarongoodwin',
#   'investigatin'],
#  ['039monsteramp039', '20', '13000'],
#  ['2'],
#  ['pcps'],
#  ['20k'],
#  ['mikeparractor'],
#  ['supernovalester'],
#  ['pllolz'],
#  ['30min', 'ckec'],
#  ['ps4',
#   '8sandscrims',
#   'empirikgaming',
#   'codawscrims',
#   '4tpkotc',
#   '4tpfa',
#   'aftershockorg'],
#  ['thedailyshow', '20s', 'jonvoyage', 'holomua'],
#  ['vzwsupport'],
#  ['sickmund', 'ncjfcj', 'ncjfcj', 'clevel'],
#  ['moscowghost', 'sayedridha', 'aminakh', '3'],
#  ['truckcrash', 'crashgt'],
#  ['mikeparractor'],
#  ['3'],
#  ['junsuisengen'],
#  ['renaomino'],
#  ['ajabrown', 'mh370'],
#  ['8620152', '09', '2781'],
#  ['3novices', 'renison', 'tasmanias', 'renison'],
#  ['ancop'],
#  ['dodgersnation'],
#  ['offensive۪'],
#  ['caixxum', '5sos'],
#  ['logitechg'],
#  ['emmeryn'],
#  ['4'],
#  ['coiffed'],
#  ['emilynoel',
#   '95',
#   'sterlingknight',
#   'joeylawrence',
#   'abcfmelissajoey',
#   'melissaandjoeychat'],
#  ['5'],
#  ['cyclonereizei', 'cyclonesama', 'rindou'],
#  ['ۢi', 'disasterۢ'],
#  ['260th'],
#  ['humanityi', 'survivorsr', 'sojapan', 'nuclearweapons'],
#  ['shgames'],
#  ['meinlcymbals', '18', 'meinlcymbals'],
#  ['9', '2'],
#  ['gtgtgt', 'gtgtgt', 'trubgme', 'gtgtgt'],
#  ['3'],
#  ['airportwatch', '2reduce'],
#  ['inundation'],
#  ['4mesews'],
#  ['viayoutube'],
#  ['0013', 'butterflieshes'],
#  ['hatchetwielding'],
#  ['gentlementhe', 'bb17'],
#  ['universityoflaw', '731'],
#  ['bags۪'],
#  ['disasteramp', '4'],
#  ['jonathanshainin'],
#  ['06', '2015', '1'],
#  ['05th', '2029'],
#  ['andygilder', '5', 'rescuersthe'],
#  ['advancedwarfare', '4'],
#  ['infoorder', '08780923344', '5', '2327564'],
#  ['robertcalifornia', 'thereisonlysex'],
#  ['schella'],
#  ['rowyso'],
#  ['cw500'],
#  ['whackamole'],
#  ['droughtfueled'],
#  ['irretrievable', 'sjfeb'],
#  ['15th', 'teamsurvivors', 'zombiefunrun', '2014'],
#  ['blowvape', '15'],
#  ['thestrain'],
# ...
#  ['titortau', 'ombudsmanship'],
#  ['antifracking'],
#  ['njenga'],
#  ['6'],
#  ['gayuk'],
#  ['here۪s'],
#  ['linkury'],
#  ['2'],
#  ['ciostrategyau'],
#  ['11'],
#  ['carryi'],
#  ['70th', '70'],
#  ['ronwyden', '48', '67'],
#  ['justbitching'],
#  ['737', '18'],
#  ['everwhe'],
#  ['flamecored'],
#  ['demoness'],
#  ['3p', '330a'],
#  ['tvjnews'],
#  ['soudelor'],
#  ['texansdc', 'kylekrenek', '1978', 'frobeusns'],
#  ['heavydirtysoul'],
#  ['riverroaming'],
#  ['attjcdemos', 'folieacat'],
#  ['15'],
#  ['husnaavhora'],
#  ['weloveyoulouis'],
#  ['ohyayyyyay'],
#  ['reshapes'],
#  ['justinejayyy'],
#  ['laevantine'],
#  ['4japan', '4japan'],
#  ['2015', 'clambake', 'showgirldayoff'],
#  ['maratha', '1943'],
#  ['3', 'zeroedge', 'duallens', 'trafficdriving', 'historyaccident'],
#  ['nalathekoala', 'sequalae'],
#  ['joinvroom', 'ohhhh', 'tangletalk'],
#  ['30'],
#  ['omgggg'],
#  ['4playthursdays', '1716', '18'],
#  ['bestdayeva'],
#  ['9'],
#  ['thorins'],
#  ['ercjmnea'],
#  ['usfs'],
#  ['2011'],
#  ['1'],
#  ['aubreys'],
#  ['indiatv'],
#  ['cartoonylike'],
#  ['lizkhalifa'],
#  ['5', '182245', 'm55', '60km', '4'],
#  ['blizzardcs'],
#  ['sensorsenso', '9096', '22lh4'],
#  ['edmundadamus', 'campionjoanne', '79'],
#  ['630'],
#  ['mh370'],
#  ['2'],
#  ['pbban', '300', 'fighterdena'],
#  ['kamkasteiiano', 'bluntedjayt'],
#  ['trinityfox'],
#  ['remainontop', 'fettilootch', 'slanglucci', 'oppressions'],
#  ['uncertaintyeconomic'],
#  ['2907201', '5'],
#  ['taraswart', 'viviangiang'],
#  ['ctafails'],
#  ['70th'],
#  ['dannyonpc', '11', 'throwingknifes'],
#  ['kainyusanagi', 'grummz', 'pixelcanuck'],
#  ['5'],
#  ['canaanites'],
#  ['ripross'],
#  ['youngheroesid', 'niastewart', '3', 'nrmawa', 'pantherattack'],
#  ['beatg', '3', '852015', '608', '15000270653'],
#  ['themalemadonna'],
#  ['hopeinhearts'],
#  ['floodzone', 'fwo'],
#  ['m151a1', 'm416'],
#  ['highestranking'],
#  ['2im'],
#  ['5sos', '1d', '5sos'],
#  ['bb4sp'],
#  ['vanquiishher'],
#  ['gtas', 'gtservers', 'gtmaintenance'],
#  ['4', 'dccc', 'vj44', 'jbouie'],
#  ['150foot'],
#  ['213296'],
#  ['beforeitsnews', 'sixmeter'],
#  ['leader۪s', '15'],
#  ['huffpostrelig'],
#  ['90s'],
#  ['kashs'],
#  ['newsarama'],
#  ['400', '25'],
#  ['8th', 'sebee'],
#  ['carryi'],
#  ['90225', '187'],
#  ['3', 'animalrescue'],
#  ['dannyonpc', '2', '1000'],
#  ['ymcglaun', 'juliekragt', 'wildwestsixgun'],
#  ['13'],
#  ['robotlvl', '1', '16000', 'satoshis', 'robotcoingame', 'freebitcoin'],
#  ['8', 'bivideo'],
#  ['90'],
#  ['ifak'],
#  ['christinalavv', 'lindsaywynn', '3'],
#  ['ۢ'],
#  ['that۪s'],
#  ['fidayeen', 'insas', 'insas'],
#  ['heartbrokenmobile', '2', '3lv'],
#  ['askcharley', '5'],
#  ['77'],
#  ['beforeitsnews', '3'],
#  ['1211'],
#  ['daborsch'],
#  ['198'],
#  ['attackclose'],
#  ['4taiji'],
#  ['12000'],
#  ['pusssssssssy', 'shoook'],
#  ['minhazmerchant'],
#  ['referential'],
#  ['bloopandablast'],
#  ['8p', 'crunchysensible'],
#  ['bioterror'],
#  ['mylittlepwnies', '3', 'earlymay', 'anathemazhiv', 'tonysandos', '80s'],
#  ['summerfate'],
#  ['jakegint'],
#  ['mollythetanzs'],
#  ['1', '60', 'kotaweather'],
#  ['guyreginald'],
#  ['mh370'],
#  ['lukebox'],
#  ['theemobrago', '64'],
#  ['tmfkco'],
#  ['89x'],
#  ['peoplecommunication'],
#  ['15', '15'],
#  ['totoooooo', 'totoooooooooo', 'historicalmages', '18th', '1935'],
#  ['rockyfire', '20', 'cafire'],
#  ['aberdeenfc', 'aberdeenfanpage'],
#  ['pandemoniumiso'],
#  ['c4news'],
#  ['onufrance',
#   '7475',
#   'bioterrorism',
#   'rockefellerchirockefellerunivheiress',
#   '2',
#   '2',
#   '4',
#   'harvardu',
#   'kidnapgafp'],
#  ['pemantaujkt', '48'],
#  ['sunnymeade'],
#  ['dinosaurdracula'],
#  ['3', 'wsea', '5seattle'],
#  ['40'],
#  ['2', 'mpmy', 'officeofrg'],
#  ['prophetmuhammad'],
#  ['adamtuss', '5000', '12007'],
#  ['i65'],
#  ['lordminion', '777'],
#  ['bridgeportspeed'],
#  ['2011', '53', '8', '16', '4'],
#  ['njturnpike'],
#  ['fromwounds'],
#  ['carolinagutierr'],
#  ['chelsdelong', '12', 'kendraleigh', '13'],
#  ['700am', '1200pm'],
#  ['40'],
#  ['wbbmnewsradio'],
#  ['thetimepast'],
#  ['an247'],
#  ['princessduck', '6th'],
#  ['bexrayandvav'],
#  ['trombonetristan', 'ooooohshit', 'ooohshit'],
#  ['follownflnews'],
#  ['48'],
#  ['rjg', '0789', 'idki', 'sterotypical', 'annddd'],
#  ['basildudin', 'saudies'],
#  ['brandonmulcahy', 'fpine'],
#  ['dorette'],
#  ['tokyodotcom'],
#  ['wildestsdream'],
#  ['magner'],
#  ['whatupdave', '2075', '1'],
#  ['lastingness', 'ziuw'],
#  ['defendbutera'],
#  ['prosyndicate', '13'],
#  ['southridgelife'],
#  ['3'],
#  ['johnsontionne'],
#  ['nagelashley', 'vicken', '52', 'basedlarock', 'goonc', '1ty'],
#  ['techfree', 'reenslave'],
#  ['petrichour'],
#  ['argentaelite'],
#  ['missinstiinctz'],
#  ['101'],
#  ['b24fowler'],
#  ['hairbut'],
#  ['hintdevastation', 'beyondthebomb'],
#  ['8'],
#  ['tanslash'],
#  ['bloodim'],
#  ['5', '5'],
#  ['danemillar', '1', '666'],
#  ['15'],
#  ['pcaldicott', '7', '7newsadl'],
#  ['10'],
#  ['56', 'oversaturated', '12m', 'regc'],
#  ['70th'],
#  ['13', 'saudimosque'],
#  ['willhillbet'],
#  ['funnychubbyguy'],
#  ['selfimage'],
#  ['soudelor'],
#  ['ghazalabaji'],
#  ['2010', '17', '15', '12', 'opseaworld'],
#  ['500'],
#  ['chicagoarea', 'theadvocatemag'],
#  ['peterduttonmp', '2'],
#  ['kotowsa', 'sudan۪s'],
#  ['77', 'rondarousey'],
#  ['3'],
#  ['sdotjr', 'ofentsetsie'],
#  ['linkury'],
#  ['beachboyirh', 'ooorrrr'],
#  ['m8'],
#  ['75'],
#  ['30'],
#  ['lanford'],
#  ['852015', '950', '1030'],
#  ['sick۪', 'hazard۪'],
#  ['schematization', 'obliterationxmwte'],
#  ['samaritans۪', 'ampmdash', 'bronville'],
#  ['11yearold', '11yearold'],
#  ['themayhoka', 'longfoxysiren'],
#  ['jessicalauraxo'],
#  ['bellybombed', 'teamstream'],
#  ['nxwestmidlands'],
#  ['modiministry'],
#  ['commoditiesare', '2008'],
#  ['aapatwork'],
#  ['humaza'],
#  ['boomshunga'],
#  ['gurmeetramrahim', 'msgdoing', '111welfareworks', '65000'],
#  ['shhhh'],
#  ['hippiexox', '24'],
#  ['york۪s'],
#  ['salvages'],
#  ['11000', '30'],
#  ['jdmarsh', '22'],
#  ['udhampur', '2', 'spos'],
#  ['newstexas'],
#  ['benews'],
#  ['vegassolitude'],
#  ['12', '23km', '2015080', '5', '235409', '2015080', '5', '165409', '070'],
#  ['bettyfreedoms', 'abninfvet'],
#  ['peterknox', 'gemmasterful'],
#  ['binellithresa', 'abuseddesolateamplost', 'diesis'],
#  ['600', 'yycstorm'],
#  ['zhenghxn', '11'],
#  ['50'],
#  ['753', '1'],
#  ['realdonaldtrump', '1965a'],
#  ['11', 'alwsl'],
#  ['10'],
#  ['fionagilbert'],
#  ['elielcruz'],
#  ['brahmans'],
#  ['4'],
#  ['712am', 'lowlying'],
#  ['3'],
#  ['2', 'jackiekatu'],
#  ['futurea'],
#  ['angusmacneilsnp', 'i۪d'],
#  ['beconfident'],
#  ['2015'],
#  ['mh370'],
#  ['4', 'iblmapleleafs', '1919'],
#  ['axwave', '2d', '3d'],
#  ['1115'],
#  ['bremorrow'],
#  ['fittscott', '20', 'popularmmos'],
#  ['lionofjudah', '1948', 'americanjewry'],
#  ['hannahkauthor', 'freeamirnow', 'freeallfour', 'irandeal'],
#  ['gilmanrocks', '7'],
#  ['thenerdsofcolor', 'georgetakei'],
#  ['wagingnv'],
#  ['damnnnn', '26'],
#  ['meganrestivo'],
#  ['authenticating'],
#  ['here۪s'],
#  ['72'],
#  ['lukewinkie'],
#  ['babybackreeve'],
#  ['naved', 'naved'],
#  ['jamucsb'],
#  ['1'],
#  ['20', 'tomclancy'],
#  ['thatwitchem', 'emmachosenone', 'jessienovoarp', 'jessienovoa', 'liananovoa'],
#  ['massmurderer'],
#  ['veldfest'],
#  ['norwaymfa'],
#  ['80ft', 'shaldon'],
#  ['shrnnclbautista'],
#  ['199899', '171', '1620'],
#  ['humaza'],
#  ['2'],
#  ['seriousnow', 'removedquarantined'],
#  ['70th', 'generalnews'],
#  ['typhoondevastated'],
#  ['46'],
#  ['lightseraphs'],
#  ['doricreates', 'alhanda'],
#  ['cityamp', '3others', '20000k'],
#  ['3rd'],
#  ['rexyy'],
#  ['don۪t'],
#  ['pseudojuuzo'],
#  ['satanaofhell'],
#  ['whyor'],
#  ['114'],
#  ['deosl', '86'],
#  ['globetrottingwino'],
#  ['texaschainsawmassacre', 'morbidmovies'],
#  ['asolidrighthook'],
#  ['mh370'],
#  ['khulna'],
#  ['a1', 'gravitychat'],
#  ['21', 'purdies'],
#  ['alvinnelson', '07'],
#  ['techesback'],
#  ['landsli'],
#  ['onlinecommunities', 'amageddon'],
#  ['pbohanna', '1st', 'justaguess'],
#  ['911call'],
#  ['bioterrorism'],
#  ['jacobhoggard', 'therealmattleaf'],
#  ['usetheiight'],
#  ['davej', '798', 'johnejefferson', 'somaliaeritrea', '28', '2014'],
#  ['reportly', 'ntvde'],
#  ['stormfree', 'eventspalmbeach'],
#  ['snazzychipz'],
#  ['sebee'],
#  ['roomsgrrrr'],
#  ['hsts', 'kimery', 'bioterrorism'],
#  ['bravesninja', 'davidbrelsford'],
#  ['jaymcleanauthor'],
#  ['christinkpix', '5', 'nightbeattv', '10pm', 'kbcwtv', 'veronicadlcruz'],
#  ['0327', '2d', '3d'],
#  ['stavernise'],
#  ['rigga'],
#  ['parleys'],
#  ['70', '70th'],
#  ['2', 'reator'],
#  ['suregod', 'butthe', 'wnukes'],
#  ['antifeminist'],
#  ['incindia', 'victorytotal'],
#  ['waterresistant'],
#  ['devjis'],
#  ['16', '0', '150'],
#  ['0'],
#  ['1'],
#  ['classycolkett'],
#  ['j3lyon'],
#  ['148', 'streetjamzdotnet'],
#  ['benjidevos', '3'],
#  ['1998', '1', '57'],
#  ['2'],
#  ['105', '49', '56', 'imkeepingmydayjob', '17'],
#  ['badging'],
#  ['typhoondevastated'],
#  ['16yr'],
#  ['20'],
#  ['goooooooo'],
#  ['udhampur', '2', 'spos'],
#  ['writebothfists'],
#  ['topherbreezy'],
#  ['otrametlife'],
#  ['nopassenger'],
#  ['kemalatlay'],
#  ['4'],
#  ['sensorsenso', 'ks100'],
#  ['suryaray', 'udhampur', '2', 'spos', 'suryaray'],
#  ['39', 'gwatt'],
#  ['hillary۪s', 'politicsisdirty'],
#  ['moregtosha', 'siteinvestigating', 'noranda', '12'],
#  ['xmankitty', 'wolvenbeauty', 'nickwilson', 'shitalright'],
#  ['localplumber'],
#  ['chikislizeth', '08'],
#  ['1984style'],
#  ['2'],
#  ['assassinkpg', 'friendshipyou'],
#  ['3', 'alrasyid', '448iturasya', '3', 'smantibatam', '3smantibatam'],
#  ['davidcovucci'],
#  ['frautrapani'],
#  ['bb4sp'],
#  ['bryansinger', 'alexshipppp'],
#  ['shipsxanchors'],
#  ['lyricaleyes'],
#  ['aptlyengineerd'],
#  ['70th'],
#  ['graysondolan'],
#  ['orangeblue', 'unsuckdcmetro'],
#  ['40', 'disea'],
#  ['suelinflower', 'painthey', 'lifeits'],
#  ['toiindianews', '8', 'caued'],
#  ['droughtmonitor', '27', '80m'],
#  ['015', '1346'],
#  ['13', '9km'],
#  ['darchambau'],
#  ['amcx', 'viab'],
#  ['ringsau', 'tb4'],
#  ['sensorsenso', 'ks225'],
#  ['screamqueens'],
#  ['2nd'],
#  ['america۪s'],
#  ['2014', '11st'],
#  ['ulcerated', 'bnvfdag'],
#  ['7eyewitness', '7', 'hometownglory'],
#  ['evahanderek', 'marleyknysh'],
#  ['kaylak', '369'],
#  ['3', 'hateviolence', 'colorlines'],
#  ['mh370'],
#  ['preseasonworkouts'],
#  ['nj36', '516leonardville'],
#  ['reddits'],
#  ['100nd'],
#  ['casperrmg', 'bestcomedyvine'],
#  ['tammyw', '1997', 'elijahmallari'],
#  ['surṳ', '32'],
#  ['mistresspip'],
#  ['ashayo', 'msmiggi', 'ashayo'],
#  ['dometufnellpark'],
#  ['mh370'],
#  ['pakistan۪s', 'antiterrorism'],
#  ['2500fps'],
#  ['soudelor', '7', '2', '7chicago'],
#  ['360'],
#  ['gradschoolapps'],
#  ['10th'],
#  ['roosevelts'],
#  ['0siris', 'boringdead', 'snotgreen'],
#  ['thomashcrown', '95'],
#  ['70'],
#  ['soloquiero', '6', 'firefighte'],
#  ['gtgtgt'],
#  ['cortneymo', 'mfsloose'],
#  ['370'],
#  ['6', '1945', 'mankinds'],
#  ['charlesdagnall', '50'],
#  ['greenharvard'],
#  ['scfd', 'lakecounty'],
#  ['localarsonist'],
#  ['715'],
#  ['bebacksoon'],
#  ['deezercolombia'],
#  ['teamnyle'],
#  ['061', 'akrams', 'carhot', '1bullet'],
#  ['3', 'hateviolence', 'dviyer', 'colorlines'],
#  ['hatcap', 'silvergray'],
#  ['informant۪s'],
#  ['12'],
#  ['beforeitsnews', 'ۢthis'],
#  ['owenrbroadhurst', 'juanmthompson', '70'],
#  ['dmassa', '5'],
#  ['tindering', '20mins'],
#  ['9', 'radioriffrocks', '2'],
#  ['nomorepod'],
#  ['magnafis', '40s', '40s'],
#  ['3', '2'],
#  ['960kzim', '2'],
#  ['mediterran'],
#  ['channelstvthats'],
#  ['kiilud'],
#  ['dantwitty', '52'],
#  ['sa15t', 'sa15t', '2', '1', '1'],
#  ['adamrubinespn', 'mattharvey', '33', '88'],
#  ['wedaug', '5th'],
#  ['udhampur', 'jampk', '2', 'spos'],
#  ['samfbiddle', 'f35s'],
#  ['6'],
#  ['4playthursdays', '1716', '18'],
#  ['15', 'dians'],
#  ['17', '101'],
#  ['13'],
#  ['336'],
#  ['kristindavis'],
#  ['offensive۪'],
#  ['xgninfinity', 'ronincarbon'],
#  ['54', '9', '6'],
#  ['inundation'],
#  ['1600yearold'],
#  ['11', '3yearold'],
#  ['salempolice', 'underskirt'],
#  ['4'],
#  ['spicenthingsup'],
#  ['codemew', '1', 'pulloneyou'],
#  ['lawsonofficial'],
#  ['hinatobot'],
#  ['monday۪s'],
#  ['11yearold', '11yearold'],
#  ['crossborder'],
#  ['halfhr'],
#  ['3'],
#  ['trafficalert', '210'],
#  ['netnewsledger', '4', '2015', 'therewere'],
#  ['careerarc'],
#  ['vilelunar'],
#  ['wisdc', '2usa'],
#  ['southline', 'yennora', 'cabramatta'],
#  ['reddits'],
#  ['livingsafely'],
#  ['strategicpatience'],
#  ['3', 'warriorcord', '100', '550', 'milc', '5040h', '7', '516'],
#  ['aisumage', 'akumareisu'],
#  ['thejonesesvoice', 'liguistic'],
#  ['jasalhad', 'brianboru', '67', 'jimskiv', '92', '1967'],
#  ['nightmarecommute'],
#  ['tltltltltlttlt', 'pgrolsh', 'metrofmtalk'],
#  ['397', 'parkchat'],
#  ['60', '60'],
#  ['4'],
#  ['375'],
#  ['2', '2', 'headon'],
#  ['rs40000cr', '3612'],
#  ['1'],
#  ['i5', 'terwilliger', 'pp15000266858', '1726', '911'],
#  ['mariasherwood', '2', 'johnjcampbell'],
#  ['gamergate'],
#  ['debatequestionswewanttohear'],
#  ['989'],
#  ['martinmj', '22', '12', '36'],
#  ['thenissonian', 'rejectdcartoons'],
#  ['70'],
#  ['savagenation', 'stalins', 'faminedeath'],
#  ['sixmeter'],
#  ['sahelnews'],
#  ['christycroley'],
#  ['aberystwythshrewsbury'],
#  ['36'],
#  ['thirdquarter'],
#  ['africanbaze', 'newsnigeria'],
#  ['kombatfans', '33'],
#  ['warfighting'],
#  ['fedporn'],
#  ['2015'],
#  ['bioterror'],
#  ['sawyerdaa', 'guerrilladawg', 'estus'],
#  ['crazyindapeg', '78734', 'ptsdchat'],
#  ['19',
#   '5km',
#   '2015080',
#   '6',
#   '010401',
#   '2015080',
#   '5',
#   '150401',
#   '1000',
#   'csismica'],
#  ['likkly'],
#  ['35w'],
#  ['emsne'],
#  ['1970', '429cj'],
#  ['82ndabndiv'],
#  ['150foot'],
#  ['gamerant', '3'],
#  ['pnutsmama'],
#  ['drumpf'],
#  ['40'],
#  ['noobde'],
#  ['summerfate'],
#  ['emekagift', 'vpsay', 'massmurderer'],
#  ['matchwood'],
#  ['weallheartonedirection', 'wouldn۪t', 'i۪m'],
#  ['79yearold'],
#  ['pbban', '300', 'russaky', '89'],
#  ['noonancindynoonanheartbreak', 'yahistorical', 'undergroundrailraod'],
#  ['superintende'],
#  ['20'],
#  ['allahsfinest', '12'],
#  ['bloodbound'],
#  ['weathernetwork'],
#  ['09'],
#  ['karnythia'],
#  ['egoresolution', '1000'],
#  ['cbcnorth', 'talston', '2010'],
#  ['japn', '3', '010217', 'm38', '10km', '3'],
#  ['peterarnottglas'],
#  ['organizationabbog'],
#  ['hurricanedolce'],
#  ['jamaicaplain'],
#  ['mordechai', '24', 'shemesh', '361'],
#  ['monopolized', 'hunhry'],
#  ['3', '1915kill', '10000'],
#  ['37'],
#  ['sweetpeas'],
#  ['samsmith'],
#  ['jackienatalydlt'],
#  ['rstormcoming'],
#  ['intldevelopment', '19'],
#  ['lunasagalle', 'synapsenkotze'],
#  ['sayingdarude'],
#  ['lovemywife', '1983', 'shedid', '911', '4the', 'washard'],
#  ['fixwmata', 'adamtuss'],
#  ['1'],
#  ['cityamp', '3others', '20000k'],
#  ['heyitsepark'],
#  ['pulwama', '2nd'],
#  ['danhrothschild', 'selfdestruction'],
#  ['versethe'],
#  ['rayquazaerk'],
#  ['ltlt'],
#  ['19', '15km', '2015080', '6', '001116', '2015080', '5', '161116', '0800'],
#  ['nosc'],
#  ['cecilthelion'],
#  ['tweetlikeitsseptember', '11th2001'],
#  ['3d', 'soudelor', 'nasahurricane'],
#  ['attackonstiles', 'apunk'],
#  ['tuicruises', 'aidade'],
#  ['jewishpress'],
#  ['5', '5sosfam'],
#  ['o۪donnell'],
#  ['2'],
#  ['100'],
#  ['452', '10x', '27w', '12v', '24v'],
#  ['chinadotcom'],
#  ['rtphotographyuk', 'southdowns'],
#  ['8', 'brucewillis', '1', '2', '12'],
#  ['calestous', '60'],
#  ['explosionproof', 'z10'],
#  ['10'],
#  ['iamtalia', '72', 'displacedinjuredkilled'],
#  ['skydragonforce'],
#  ['irannucleardeal'],
#  ['rightways'],
#  ['reasonvsfear', 'hijackings'],
#  ['typhoondevastated'],
#  ['icymagistrate'],
#  ['salivation', 'kegm'],
#  ['akcsl'],
#  ['stighefootball'],
#  ['allenpeacock', 'cleariran', 'bombedits'],
#  ['2'],
#  ['pamanian'],
#  ['rosannebarr'],
#  ['elwoods', 'blazingelwoods'],
#  ['ep016', '2015080', '6'],
#  ['600'],
#  ['917033'],
#  ['7seattle'],
#  ['japn', '154107', '0'],
#  ['gopcontrolled'],
#  ['dannyonpc', '11', 'throwingknifes'],
#  ['kijimamatako'],
#  ['2'],
#  ['microlight'],
#  ['gtiso', 'nzmorningreport', 'aucklnd'],
#  ['30'],
#  ['dopeitsval'],
#  ['dorrian'],
#  ['lilithsaintcrow'],
#  ['2'],
#  ['momentsathill'],
#  ['aparra', '210'],
#  ['4', '30'],
#  ['freshoutofthebox', 'getitbeforeitsgone', '50', 'newnewnew'],
#  ['m9a1', 'phrobis'],
#  ['warthen'],
#  ['21', '29800'],
#  ['strategicpatience'],
#  ['5', 'ibalita'],
#  ['rs5'],
#  ['735m'],
#  ['explodelight', 'realmandyrain'],
#  ['mh370', 'billneelynbc'],
#  ['windstormfollow'],
#  ['3'],
#  ['labourleadership'],
#  ['aphl', 'bioterror'],
#  ['4', 'policerun', '7'],
#  ['2'],
#  ['iiii'],
#  ['arizonadot'],
#  ['3'],
#  ['betrayedhunter'],
#  ['broseidonrex', 'dapurplesharpie'],
#  ['ineedcake'],
#  ['fusionfestival'],
#  ['247'],
#  ['tontitowngrape', '2015'],
#  ['kshllcenterpri', '1', '4ohio'],
#  ['zaynmaiikist'],
#  ['smartteks', 'gpsbased', 'mpers'],
#  ['19', '5km', '2015080', '6', '010401', '2015080', '5', '150401', '1000'],
#  ['presinkhole'],
#  ['rtirishirr', 'mchapmanwsaz', 'wsazbrittany', 'kellyannwx'],
#  ['cranboonitz', 'hereticofethics'],
#  ['funtenna', '2015', 'prebreak']]
# (5898, 25)

# %%
# from sklearn.decomposition import TruncatedSVD

# # Step 1: Concatenate Embeddings
# all_embeddings = np.vstack((df_train_text_embedded_w2v.values, df_test_text_embedded_w2v.values))

# # Step 2: Apply LSA
# # Choose the number of components for LSA
# n_components = 500  # Example, adjust this based on your needs
# lsa = TruncatedSVD(n_components=n_components)

# # Fit and transform the embeddings
# all_embeddings_reduced = lsa.fit_transform(all_embeddings)

# # Step 3: Split the Transformed Data
# train_size = df_train_text_embedded_w2v.shape[0]
# df_train_reduced = all_embeddings_reduced[:train_size]
# df_test_reduced = all_embeddings_reduced[train_size:]

# df_train_reduced = pd.DataFrame(np.vstack(df_train_reduced), columns=[f'w2v_{i}' for i in range(n_components)])
# df_test_reduced = pd.DataFrame(np.vstack(df_test_reduced), columns=[f'w2v_{i}' for i in range(n_components)])

# %%
keys = [x.lower() for x in ['Paris', 'Python', 'Sunday', 'Tolstoy', 'Twitter', 'bachelor', 'delivery', 'election', 'expensive', 'experience', 'financial', 'food', 'iOS', 'peace', 'release', 'war']]

embedding_clusters = []
word_clusters = []
for word in keys:
    embeddings = []
    words = []
    for similar_word, _ in model_w2v.most_similar(word, topn=30):
        words.append(similar_word)
        embeddings.append(model_w2v[similar_word])
    embedding_clusters.append(embeddings)
    word_clusters.append(words)

# %%
from sklearn.manifold import TSNE
import numpy as np

embedding_clusters = np.array(embedding_clusters)
n, m, k = embedding_clusters.shape
tsne_model_en_2d = TSNE(perplexity=15, n_components=2, init='pca', n_iter=3500, random_state=32)
embeddings_en_2d = np.array(tsne_model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))).reshape(n, m, 2)
# Out:
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:996: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %% [markdown]
# ## 3. Selecting features

# %%
df_train.columns
# Out:
# Index(['target', 'text', 'keyword', 'text_raw', 'text_length', 'hashtag_count',
#        'mention_count', 'has_url'],
#       dtype='object')

# %%
features_to_keep = ['target', 'text_length', 'hashtag_count', 'mention_count', 'has_url']

X_train = pd.concat([
    df_train[features_to_keep], 
    df_train_text_embedded_w2v,
    ], axis=1)
X_test = pd.concat([
    df_test[features_to_keep], 
    df_test_text_embedded_w2v,
    ], axis=1)

X_train.dropna(inplace=True)

# extract y_train and y_test here to avoid column name collision with 'target' feature coming from text and keyword embeddings
y_train = X_train['target']
y_test = X_test['target']

X_train.drop(['target'], axis=1, inplace=True)
X_test.drop(['target'], axis=1, inplace=True)

(X_train.shape, y_train.shape), (X_test.shape, y_test.shape)
# Out:
# (((4098, 29), (4098,)), ((2176, 29), (2176,)))

# %% [markdown]
# ## 4. Modelling

# %%
logreg = True
svm = False
xgb = True
random_forest = False

# %%
def print_results(y_pred, y_train, y_pred_test, y_test):
    print("Train results")
    print("-----------------------------")
    print("Train accuracy: {}".format(accuracy_score(y_train, y_pred)))
    print(classification_report(y_train, y_pred))
    print(confusion_matrix(y_train, y_pred))

    print()
    print("Test results")
    print("-----------------------------")
    print("Test accuracy: {}".format(accuracy_score(y_test, y_pred_test)))
    print(classification_report(y_test, y_pred_test))
    print(confusion_matrix(y_test, y_pred_test))

# %% [markdown]
# ### Logistic regression

# %%
logreg = LogisticRegression(random_state=42, solver="liblinear")
logreg.fit(X_train, y_train)

y_pred = cross_val_predict(logreg, X_train, y_train, cv=5)  # 5-fold cross-validation
y_pred_test = logreg.predict(X_test)

print_results(y_pred, y_train, y_pred_test, y_test)
# Out:
# Train results
# -----------------------------
# Train accuracy: 0.648365056124939
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.77      0.73      2507
#          1.0       0.56      0.46      0.50      1591
#
#     accuracy                           0.65      4098
#    macro avg       0.62      0.61      0.62      4098
# weighted avg       0.64      0.65      0.64      4098
#
# [[1929  578]
#  [ 863  728]]
#
# Test results
# -----------------------------
# Test accuracy: 0.6291360294117647
#               precision    recall  f1-score   support
#
#            0       0.65      0.74      0.69      1219
#            1       0.60      0.49      0.54       957
#
#     accuracy                           0.63      2176
#    macro avg       0.62      0.61      0.61      2176
# weighted avg       0.62      0.63      0.62      2176
#
# [[904 315]
#  [492 465]]

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# print shapes
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

clf = RandomForestClassifier()
clf.fit(X_train, y_train)

# Making predictions on the test set
y_pred_train = cross_val_predict(clf, X_train, y_train, cv=5)
y_pred_test = clf.predict(X_test)
# Out:
# (4098, 29) (4098,)
# (2176, 29) (2176,)

# %%
print_results(y_pred_train, y_train, y_pred_test, y_test)
# Out:
# Train results
# -----------------------------
# Train accuracy: 0.6281112737920937
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.79      0.72      2507
#          1.0       0.53      0.37      0.44      1591
#
#     accuracy                           0.63      4098
#    macro avg       0.60      0.58      0.58      4098
# weighted avg       0.61      0.63      0.61      4098
#
# [[1978  529]
#  [ 995  596]]
#
# Test results
# -----------------------------
# Test accuracy: 0.6194852941176471
#               precision    recall  f1-score   support
#
#            0       0.63      0.79      0.70      1219
#            1       0.60      0.40      0.48       957
#
#     accuracy                           0.62      2176
#    macro avg       0.61      0.60      0.59      2176
# weighted avg       0.62      0.62      0.60      2176
#
# [[961 258]
#  [570 387]]

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# Define the parameter grid
param_distributions = {
    'n_estimators': [20, 65, 100, 150, 200],  # You can increase the range
    'max_depth': [1, 10, 20, 30, 40, 50],    # More options for depth
    'min_samples_split': [2, 5, 10, 15, 20],    # Wider range
    'min_samples_leaf': [1, 2, 4, 6, 8],        # Wider range
    'max_features': ['auto', 'sqrt', 'log2']    # Different options for max features
}

# Create a RandomForestClassifier instance
clf = RandomForestClassifier()

# Create a RandomizedSearchCV instance
random_search = RandomizedSearchCV(estimator=clf, param_distributions=param_distributions, 
                                   n_iter=100, cv=5, verbose=2, random_state=42, n_jobs=-1)

# Fit the random search to the data
random_search.fit(X_train, y_train)

# Print the best parameters
print("Best parameters found: ", random_search.best_params_)

# Use the best estimator to make predictions
best_clf = random_search.best_estimator_
y_pred_train = best_clf.predict(X_train)
y_pred_test = best_clf.predict(X_test)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=100; total time=   2.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=100; total time=   3.0s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=100; total time=   3.0s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=100; total time=   3.0s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=100; total time=   3.0s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   7.3s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   7.4s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   7.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=200; total time=   4.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=200; total time=   5.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=200; total time=   5.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   7.2s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   7.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=200; total time=   5.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=200; total time=   5.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=300; total time=   9.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=300; total time=   8.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=300; total time=   8.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=300; total time=   9.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=300; total time=   9.8s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=100; total time=   4.1s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=100; total time=   4.7s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=100; total time=   4.5s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=100; total time=   4.3s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=100; total time=   4.4s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  21.2s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  21.0s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  21.7s
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  11.6s
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  11.2s
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  10.9s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  21.1s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  21.7s
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  10.8s
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  10.7s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=15, n_estimators=200; total time=   6.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  11.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  11.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  11.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  11.5s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=15, n_estimators=200; total time=   6.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  11.4s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=15, n_estimators=200; total time=   6.5s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=15, n_estimators=200; total time=   6.4s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=   3.8s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=   3.6s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=   3.8s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=15, n_estimators=200; total time=   6.7s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=   3.6s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=   3.8s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=6, min_samples_split=20, n_estimators=200; total time=   3.9s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=6, min_samples_split=20, n_estimators=200; total time=   3.8s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=6, min_samples_split=20, n_estimators=200; total time=   3.8s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   8.0s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   8.0s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   8.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   8.2s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=6, min_samples_split=20, n_estimators=200; total time=   3.8s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=6, min_samples_split=20, n_estimators=200; total time=   3.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   8.4s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   7.6s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   7.1s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   7.2s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   7.0s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   7.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   7.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   6.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   7.4s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  18.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  18.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  18.4s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   7.3s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   7.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  17.9s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=15, n_estimators=300; total time=   9.5s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  18.1s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.0s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.0s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=15, n_estimators=300; total time=   9.6s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=15, n_estimators=300; total time=   9.7s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=15, n_estimators=300; total time=   9.7s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.1s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=15, n_estimators=300; total time=   9.9s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.0s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.1s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.1s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.2s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   7.9s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   8.2s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   8.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   8.1s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   8.6s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  14.2s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  13.9s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  14.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=20, n_estimators=500; total time=   9.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=20, n_estimators=500; total time=   9.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=20, n_estimators=500; total time=   9.3s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  13.9s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  13.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=200; total time=   5.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=200; total time=   5.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   3.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=200; total time=   5.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=200; total time=   5.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=20, n_estimators=500; total time=   9.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=20, n_estimators=500; total time=   9.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   3.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=200; total time=   5.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   3.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   3.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   3.7s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   3.8s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   3.4s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   3.7s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   3.6s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   3.6s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=500; total time=  17.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=500; total time=  17.7s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=500; total time=  18.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=500; total time=  17.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=500; total time=  18.0s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=300; total time=   4.5s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=300; total time=   4.5s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=300; total time=   4.6s
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=2, min_samples_split=20, n_estimators=500; total time=  17.9s
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=2, min_samples_split=20, n_estimators=500; total time=  18.0s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=300; total time=   4.9s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=300; total time=   5.0s
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=2, min_samples_split=20, n_estimators=500; total time=  18.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=300; total time=   6.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=300; total time=   5.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=300; total time=   5.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=300; total time=   6.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=6, min_samples_split=5, n_estimators=300; total time=   5.7s
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=2, min_samples_split=20, n_estimators=500; total time=  18.7s
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=2, min_samples_split=20, n_estimators=500; total time=  18.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   6.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  12.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  11.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   6.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   6.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  12.1s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  12.1s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=  12.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   6.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=   6.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=6, min_samples_split=15, n_estimators=500; total time=  15.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=6, min_samples_split=15, n_estimators=500; total time=  15.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=6, min_samples_split=15, n_estimators=500; total time=  16.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=6, min_samples_split=15, n_estimators=500; total time=  16.1s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=  13.6s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=  13.5s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=6, min_samples_split=15, n_estimators=500; total time=  15.7s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=  13.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   6.7s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   8.8s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   8.6s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   9.2s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   8.7s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=   9.0s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=  13.0s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=  13.3s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   3.4s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   3.3s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   6.7s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   3.5s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   7.0s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   6.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   7.0s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   3.6s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=100; total time=   1.4s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   3.5s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=100; total time=   1.4s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   6.0s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   6.0s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   6.0s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   5.8s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   5.6s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=6, min_samples_split=15, n_estimators=200; total time=   5.8s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=20, n_estimators=500; total time=  14.6s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=20, n_estimators=500; total time=  14.7s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=20, n_estimators=500; total time=  14.9s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=20, n_estimators=500; total time=  15.0s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=20, n_estimators=500; total time=  14.9s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=6, min_samples_split=15, n_estimators=200; total time=   6.4s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=6, min_samples_split=15, n_estimators=200; total time=   6.4s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=6, min_samples_split=15, n_estimators=200; total time=   6.5s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=6, min_samples_split=15, n_estimators=200; total time=   6.6s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  14.2s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  13.9s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  14.6s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  14.8s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   3.1s
# [CV] END max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  14.3s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   3.1s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   3.1s
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   3.1s
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   3.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  18.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  18.7s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.9s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  18.7s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.9s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   3.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   3.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   3.2s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   3.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=   3.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   3.5s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   3.7s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   3.8s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   4.1s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   4.4s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   4.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  19.3s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   4.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  19.7s
# ...
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=100; total time=   3.0s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=100; total time=   3.0s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=100; total time=   3.1s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=100; total time=   3.3s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=20, n_estimators=100; total time=   3.0s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=500; total time=  14.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=500; total time=  14.8s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=500; total time=  14.7s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=500; total time=  15.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=500; total time=  14.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   7.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   6.8s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   6.9s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  12.3s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  12.6s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  12.8s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  12.5s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  12.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   7.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   7.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=400; total time=  12.0s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=400; total time=  12.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=400; total time=  12.0s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   9.9s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=400; total time=  12.2s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   9.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=400; total time=  11.9s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   9.6s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   9.1s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   9.3s
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   9.9s
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   9.8s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=8, min_samples_split=15, n_estimators=500; total time=   8.0s
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=   9.8s
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  10.2s
# [CV] END max_depth=50, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  10.3s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   3.6s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   3.6s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=8, min_samples_split=15, n_estimators=500; total time=   7.8s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=8, min_samples_split=15, n_estimators=500; total time=   8.1s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   3.6s
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   3.7s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=8, min_samples_split=15, n_estimators=500; total time=   7.8s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   3.5s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=8, min_samples_split=15, n_estimators=500; total time=   7.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=20, n_estimators=200; total time=   6.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=20, n_estimators=200; total time=   5.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=20, n_estimators=200; total time=   5.8s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=15, n_estimators=400; total time=  11.4s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=15, n_estimators=400; total time=  12.2s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=15, n_estimators=400; total time=  11.9s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=15, n_estimators=400; total time=  11.7s
# [CV] END max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=15, n_estimators=400; total time=  12.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=20, n_estimators=200; total time=   6.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=20, n_estimators=200; total time=   6.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=8, min_samples_split=15, n_estimators=400; total time=   7.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=8, min_samples_split=15, n_estimators=400; total time=   7.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=8, min_samples_split=15, n_estimators=400; total time=   7.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=8, min_samples_split=15, n_estimators=400; total time=   7.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=8, min_samples_split=15, n_estimators=400; total time=   7.4s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=400; total time=  14.0s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=400; total time=  13.7s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=400; total time=  14.0s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=400; total time=  13.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=15, n_estimators=400; total time=  13.8s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=5, n_estimators=400; total time=  14.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=15, n_estimators=400; total time=  13.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=15, n_estimators=400; total time=  14.3s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=20, n_estimators=500; total time=   9.2s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=20, n_estimators=500; total time=   8.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=15, n_estimators=400; total time=  12.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=6, min_samples_split=15, n_estimators=400; total time=  12.6s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=20, n_estimators=500; total time=   7.8s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=20, n_estimators=500; total time=   7.9s
# [CV] END max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=20, n_estimators=500; total time=   7.9s
# /opt/homebrew/anaconda3/envs/ag/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Best parameters found:  {'n_estimators': 200, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': 50}

# %%
print_results(y_pred_train, y_train, y_pred_test, y_test)
# Out:
# Train results
# -----------------------------
# Train accuracy: 0.9948755490483162
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      2507
#          1.0       1.00      0.99      0.99      1591
#
#     accuracy                           0.99      4098
#    macro avg       1.00      0.99      0.99      4098
# weighted avg       0.99      0.99      0.99      4098
#
# [[2507    0]
#  [  21 1570]]
#
# Test results
# -----------------------------
# Test accuracy: 0.5896139705882353
#               precision    recall  f1-score   support
#
#            0       0.59      0.88      0.71      1219
#            1       0.59      0.22      0.32       957
#
#     accuracy                           0.59      2176
#    macro avg       0.59      0.55      0.51      2176
# weighted avg       0.59      0.59      0.54      2176
#
# [[1070  149]
#  [ 744  213]]

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score, classification_report

# Creating an XGBoost classifier
model = xgb.XGBClassifier(max_depth=1, random_state=0)

# Training the model on the training data
model.fit(X_train, y_train)

# Making predictions on the test set
y_pred_test = model.predict(X_test)

# Calculating accuracy on test set
accuracy_test = accuracy_score(y_test, y_pred_test)

# Making predictions on the training set
predictions_train = model.predict(X_train)

# Calculating accuracy on training set
accuracy_train = accuracy_score(y_train, predictions_train)

print("\nTraining Set Metrics:")
print("Accuracy:", accuracy_train)
print("\nClassification Report:")
print(classification_report(y_train, predictions_train))

print("\nTest Set Metrics:")
print("Accuracy:", accuracy_test)
print("\nClassification Report:")
print(classification_report(y_test, y_pred_test))
# Out:
# Training Set Metrics:
# Accuracy: 0.7103465104929234
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.84      0.78      2507
#          1.0       0.66      0.51      0.58      1591
#
#     accuracy                           0.71      4098
#    macro avg       0.70      0.67      0.68      4098
# weighted avg       0.70      0.71      0.70      4098
#
#
# Test Set Metrics:
# Accuracy: 0.6245404411764706
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.64      0.77      0.70      1219
#            1       0.60      0.44      0.51       957
#
#     accuracy                           0.62      2176
#    macro avg       0.62      0.60      0.60      2176
# weighted avg       0.62      0.62      0.61      2176
